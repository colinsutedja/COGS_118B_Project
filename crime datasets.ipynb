# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\krist\appdata\local\programs\python\python311\lib\site-packages (2.0.1)

# %%
import doctest
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.datasets import make_blobs
from scipy.stats import multivariate_normal
from matplotlib.patches import Ellipse
from sklearn.neighbors import NearestNeighbors
from geopy.distance import geodesic
import re

# two useful data viz libraries
import matplotlib.pyplot as plt
import seaborn as sns
# setup plotting in a notebook in a reasonable way
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# default figure aesthetics I'll be using, 
# there are other choices, see seaborn docs
sns.set_style("white")
sns.set_context("notebook")

# %%
def remove_nums_from_string(input_string):
    return re.sub(r'\d', '', input_string)

# %%
us_state_dictionary = {
    "ALABAMA": "AL",
    "ALASKA": "AK",
    "ARIZONA": "AZ",
    "ARKANSAS": "AR",
    "CALIFORNIA": "CA",
    "COLORADO": "CO",
    "CONNECTICUT": "CT",
    "DELAWARE": "DE",
    "FLORIDA": "FL",
    "GEORGIA": "GA",
    "HAWAII": "HI",
    "IDAHO": "ID",
    "ILLINOIS": "IL",
    "INDIANA": "IN",
    "IOWA": "IA",
    "KANSAS": "KS",
    "KENTUCKY": "KY",
    "LOUISIANA": "LA",
    "MAINE": "ME",
    "MARYLAND": "MD",
    "MASSACHUSETTS": "MA",
    "MICHIGAN": "MI",
    "MINNESOTA": "MN",
    "MISSISSIPPI": "MS",
    "MISSOURI": "MO",
    "MONTANA": "MT",
    "NEBRASKA": "NE",
    "NEVADA": "NV",
    "NEW HAMPSHIRE": "NH",
    "NEW JERSEY": "NJ",
    "NEW MEXICO": "NM",
    "NEW YORK": "NY",
    "NORTH CAROLINA": "NC",
    "NORTH DAKOTA": "ND",
    "OHIO": "OH",
    "OKLAHOMA": "OK",
    "OREGON": "OR",
    "PENNSYLVANIA": "PA",
    "RHODE ISLAND": "RI",
    "SOUTH CAROLINA": "SC",
    "SOUTH DAKOTA": "SD",
    "TENNESSEE": "TN",
    "TEXAS": "TX",
    "UTAH": "UT",
    "VERMONT": "VT",
    "VIRGINIA": "VA",
    "WASHINGTON": "WA",
    "WEST VIRGINIA": "WV",
    "WISCONSIN": "WI",
    "WYOMING": "WY",
    "DISTRICT OF COLUMBIA": "DC",
}

# %% [markdown]
# ### read in crime dataset 1

# %%
crime_40_60_df = pd.read_csv(r"archive (3)\crime_40_60.csv")
crime_40_60_df
# Out:
#            states                                cities population  \
# 0    Pennsylvania  Abington Township, Montgomery County     55,731
# 1          Oregon                                Albany     51,084
# 2       Louisiana                            Alexandria     48,449
# 3      California                           Aliso Viejo     48,999
# 4         Florida                     Altamonte Springs     42,296
# ..            ...                                   ...        ...
# 353    California                              Woodland     56,323
# 354  Rhode Island                            Woonsocket     41,147
# 355         Texas                                 Wylie     43,645
# 356  Pennsylvania                                  York     43,955
# 357    California                               Yucaipa     52,622
#
#      violent_crime  murder   rape  robbery  agrv_assault  prop_crime  \
# 0            197.4     1.8   14.4     70.0         111.2      1979.1
# 1             86.1     0.0   19.6     45.0          21.5      3092.9
# 2           1682.2    18.6   28.9    293.1        1341.6      7492.4
# 3             87.8     0.0    0.0     12.2          75.5       847.0
# 4            335.7     2.4   21.3     82.8         229.3      3057.0
# ..             ...     ...    ...      ...           ...         ...
# 353          314.3     0.0   17.8     83.4         213.1      3080.4
# 354          534.7     0.0   55.9    143.4         335.4      3059.8
# 355           64.2     4.6    2.3      6.9          50.4      1404.5
# 356         1335.5    25.0  100.1    430.0         780.3      3599.1
# 357          226.1     0.0    9.5     66.5         150.1      1793.9
#
#      burglary  larceny  vehicle_theft
# 0       296.1   1650.8           32.3
# 1       438.5   2470.4          184.0
# 2      2010.4   5102.3          379.8
# 3       208.2    612.3           26.5
# 4       427.9   2463.6          165.5
# ..        ...      ...            ...
# 353     640.9   2080.9          358.6
# 354     840.9   2041.5          177.4
# 355     229.1   1111.2           64.2
# 356     985.1   2388.8          225.2
# 357     515.0   1062.3          216.6
#
# [358 rows x 12 columns]

# %%
crime_60_100_df = pd.read_csv(r"archive (3)\crime_60_100.csv")
crime_60_100_df
# Out:
#            states              cities population violent_crime murder   rape  \
# 0      California             Alameda     75,467         212.0    1.3  11.91
# 1         Georgia              Albany     78,512       1,035.5    5.1   34.4
# 2        New York              Albany     98,187         816.8    4.1   43.8
# 3      California            Alhambra     84,469         176.4      -    2.4
# 4           Texas               Allen     88,783          61.9      -   12.4
# ..            ...                 ...        ...           ...    ...    ...
# 300    California         Yorba Linda     65,820          80.5      -    4.6
# 301  Pennsylvania  York Area Regional     60,732         120.2    1.6   23.1
# 302          Ohio          Youngstown     66,567       1,027.5   33.0   58.6
# 303    California           Yuba City     65,653         376.2    6.1   33.5
# 304       Arizona                Yuma     95,568         531.6    5.2   28.3
#
#      robbery agrv_assault prop_crime burglary  larceny vehicle_theft
# 0      106.0         92.8    2,507.1    392.2  1,723.9         390.9
# 1      285.3        710.7    6,369.7  1,793.4  4,291.1         285.3
# 2      253.6        515.3    4,420.1    903.4  3,359.9         156.8
# 3       78.1         95.9    2,271.8    384.8  1,585.2         301.9
# 4       14.6         34.9    1,612.9    242.2  1,321.2          49.6
# ..       ...          ...        ...      ...      ...           ...
# 300     16.7         59.3    1,195.7    338.8    808.3          48.6
# 301     26.3         69.2    1,052.2    260.2    759.1          32.9
# 302    366.5        569.4    5,462.2  2,612.4  2,435.1         414.6
# 303     65.5        271.1    3,018.9    763.1  1,975.5         280.3
# 304     63.8        434.2    3,508.5    999.3  2,262.3         246.9
#
# [305 rows x 12 columns]

# %%
for i in ['violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']:
    crime_60_100_df[i] = crime_60_100_df[i].str.replace(',', '')
    crime_60_100_df[i] = crime_60_100_df[i].astype(float)
crime_60_100_df
# Out:
#            states              cities population  violent_crime murder   rape  \
# 0      California             Alameda     75,467          212.0    1.3  11.91
# 1         Georgia              Albany     78,512         1035.5    5.1   34.4
# 2        New York              Albany     98,187          816.8    4.1   43.8
# 3      California            Alhambra     84,469          176.4      -    2.4
# 4           Texas               Allen     88,783           61.9      -   12.4
# ..            ...                 ...        ...            ...    ...    ...
# 300    California         Yorba Linda     65,820           80.5      -    4.6
# 301  Pennsylvania  York Area Regional     60,732          120.2    1.6   23.1
# 302          Ohio          Youngstown     66,567         1027.5   33.0   58.6
# 303    California           Yuba City     65,653          376.2    6.1   33.5
# 304       Arizona                Yuma     95,568          531.6    5.2   28.3
#
#      robbery agrv_assault  prop_crime burglary  larceny  vehicle_theft
# 0      106.0         92.8      2507.1    392.2   1723.9          390.9
# 1      285.3        710.7      6369.7  1,793.4   4291.1          285.3
# 2      253.6        515.3      4420.1    903.4   3359.9          156.8
# 3       78.1         95.9      2271.8    384.8   1585.2          301.9
# 4       14.6         34.9      1612.9    242.2   1321.2           49.6
# ..       ...          ...         ...      ...      ...            ...
# 300     16.7         59.3      1195.7    338.8    808.3           48.6
# 301     26.3         69.2      1052.2    260.2    759.1           32.9
# 302    366.5        569.4      5462.2  2,612.4   2435.1          414.6
# 303     65.5        271.1      3018.9    763.1   1975.5          280.3
# 304     63.8        434.2      3508.5    999.3   2262.3          246.9
#
# [305 rows x 12 columns]

# %%
crime_100_250_df = pd.read_csv(r"archive (3)\crime_100_250.csv")
crime_100_250_df
# Out:
#              states               cities population violent_crime murder  \
# 0             Texas              Abilene    119,886         393.7    2.5
# 1              Ohio                Akron    198,390         886.6   12.1
# 2          Virginia           Alexandria    145,892         166.6      -
# 3      Pennsylvania            Allentown    119,334         547.2   12.6
# 4             Texas             Amarillo    196,576         650.1    5.1
# ..              ...                  ...        ...           ...    ...
# 207  North Carolina           Wilmington    109,370         565.1    7.3
# 208  North Carolina        Winston-Salem    234,687           663    2.6
# 209      New Jersey  Woodbridge Township    100,612         121.3      -
# 210   Massachusetts            Worcester    183,247         959.4    4.4
# 211        New York              Yonkers    198,464         570.9      2
#
#      rape  robbery agrv_assault prop_crime burglary  larceny vehicle_theft
# 0    31.7    105.9        253.6    3,664.3      865  2,656.7         142.6
# 1    84.2    290.8        499.5    5,057.7  1,728.4  2,965.9         363.4
# 2     6.2     94.6         65.8    2,049.5    192.6  1,633.4         223.5
# 3    45.3    313.4          176    3,857.2  1,045.8  2,503.1         308.4
# 4    56.0    141.4        447.7    4,527.5  1,061.7  3,145.9           320
# ..    ...      ...          ...        ...      ...      ...           ...
# 207  21.0    238.6        298.1    5,403.7  1,548.9  3,513.8           341
# 208  31.5    182.4        446.6      5,838  1,929.8  3,617.6         290.6
# 209   3.0     54.7         63.6      1,955    335.9  1,504.8         114.3
# 210  18.0    228.7        708.3      3,510  1,113.3    2,143         253.8
# 211  14.1    212.6        342.1    1,292.4    269.6    906.5         116.4
#
# [212 rows x 12 columns]

# %%
for i in ['violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']:
    crime_100_250_df[i] = crime_100_250_df[i].str.replace(',', '')
    crime_100_250_df[i] = crime_100_250_df[i].astype(float)
crime_100_250_df
# Out:
#              states               cities population  violent_crime murder  \
# 0             Texas              Abilene    119,886          393.7    2.5
# 1              Ohio                Akron    198,390          886.6   12.1
# 2          Virginia           Alexandria    145,892          166.6      -
# 3      Pennsylvania            Allentown    119,334          547.2   12.6
# 4             Texas             Amarillo    196,576          650.1    5.1
# ..              ...                  ...        ...            ...    ...
# 207  North Carolina           Wilmington    109,370          565.1    7.3
# 208  North Carolina        Winston-Salem    234,687          663.0    2.6
# 209      New Jersey  Woodbridge Township    100,612          121.3      -
# 210   Massachusetts            Worcester    183,247          959.4    4.4
# 211        New York              Yonkers    198,464          570.9      2
#
#      rape  robbery agrv_assault  prop_crime burglary  larceny  vehicle_theft
# 0    31.7    105.9        253.6      3664.3      865   2656.7          142.6
# 1    84.2    290.8        499.5      5057.7  1,728.4   2965.9          363.4
# 2     6.2     94.6         65.8      2049.5    192.6   1633.4          223.5
# 3    45.3    313.4          176      3857.2  1,045.8   2503.1          308.4
# 4    56.0    141.4        447.7      4527.5  1,061.7   3145.9          320.0
# ..    ...      ...          ...         ...      ...      ...            ...
# 207  21.0    238.6        298.1      5403.7  1,548.9   3513.8          341.0
# 208  31.5    182.4        446.6      5838.0  1,929.8   3617.6          290.6
# 209   3.0     54.7         63.6      1955.0    335.9   1504.8          114.3
# 210  18.0    228.7        708.3      3510.0  1,113.3   2143.0          253.8
# 211  14.1    212.6        342.1      1292.4    269.6    906.5          116.4
#
# [212 rows x 12 columns]

# %%
crime_250_plus_df = pd.read_csv(r"archive (3)\crime_250_plus.csv")
crime_250_plus_df.rename(columns = {'tot_violent_crime':'violent_crime'}, inplace=True)
crime_250_plus_df.rename(columns = {'tot_prop_crim':'prop_crime'}, inplace=True)
crime_250_plus_df
# Out:
#          states          cities population  total_crime  murder    rape  \
# 0       Alabama         Mobile3    248,431      6217.02   20.13   58.16
# 1        Alaska       Anchorage    296,188      6640.04    9.12  132.01
# 2       Arizona        Chandler    249,355      2589.08    2.01   52.13
# 3       Arizona         Gilbert    242,090      1483.75    2.07   16.11
# 4       Arizona        Glendale    249,273      5037.85    4.81   38.91
# ..          ...             ...        ...          ...     ...     ...
# 95     Virginia  Virginia Beach    454,353      2083.40    3.08   22.45
# 96   Washington         Seattle    721,365      5911.99    3.74   36.87
# 97   Washington         Spokane    217,066      7881.01    2.76  109.64
# 98    Wisconsin         Madison    255,850      3040.46    4.30   37.13
# 99    Wisconsin       Milwaukee    595,168      5441.99   19.83   72.92
#
#     robbery agrv_assault violent_crime  burglary   larceny vehicle_theft  \
# 0    177.11       485.85        740.25  1,216.84  3,730.21        506.78
# 1    262.67       799.49      1,203.29    748.17  3,619.66      1,047.98
# 2     56.95       148.38        259.47    314.41  1,866.01        149.18
# 3     21.07        46.26         85.51    192.49  1,137.59         55.76
# 4    192.96       251.53        488.22    637.45  3,426.36        466.56
# ..      ...          ...           ...       ...       ...           ...
# 95    59.87        52.16        137.56    165.95  1,667.65        101.02
# 96   210.02       382.05        632.69  1,081.98  3,673.45        503.21
# 97   105.50       408.63        626.54  1,023.19  5,408.03        800.22
# 98    82.86       250.15        374.44    362.32  2,130.94        168.85
# 99   490.45     1,014.17      1,597.36    927.13  1,940.29        924.61
#
#    prop_crime  arson
# 0    5,453.83  22.94
# 1    5,415.82  20.93
# 2    2,329.61    NaN
# 3    1,385.85  12.39
# 4    4,530.37  19.26
# ..        ...    ...
# 95   1,934.62  11.22
# 96   5,258.64  20.66
# 97   7,231.44  23.03
# 98   2,662.11   3.91
# 99   3,792.04  52.59
#
# [100 rows x 14 columns]

# %%
for i in ['violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']:
    crime_250_plus_df[i] = crime_250_plus_df[i].str.replace(',', '')
    crime_250_plus_df[i] = crime_250_plus_df[i].astype(float)
crime_250_plus_df
# Out:
#          states          cities population  total_crime  murder    rape  \
# 0       Alabama         Mobile3    248,431      6217.02   20.13   58.16
# 1        Alaska       Anchorage    296,188      6640.04    9.12  132.01
# 2       Arizona        Chandler    249,355      2589.08    2.01   52.13
# 3       Arizona         Gilbert    242,090      1483.75    2.07   16.11
# 4       Arizona        Glendale    249,273      5037.85    4.81   38.91
# ..          ...             ...        ...          ...     ...     ...
# 95     Virginia  Virginia Beach    454,353      2083.40    3.08   22.45
# 96   Washington         Seattle    721,365      5911.99    3.74   36.87
# 97   Washington         Spokane    217,066      7881.01    2.76  109.64
# 98    Wisconsin         Madison    255,850      3040.46    4.30   37.13
# 99    Wisconsin       Milwaukee    595,168      5441.99   19.83   72.92
#
#     robbery agrv_assault  violent_crime  burglary  larceny  vehicle_theft  \
# 0    177.11       485.85         740.25  1,216.84  3730.21         506.78
# 1    262.67       799.49        1203.29    748.17  3619.66        1047.98
# 2     56.95       148.38         259.47    314.41  1866.01         149.18
# 3     21.07        46.26          85.51    192.49  1137.59          55.76
# 4    192.96       251.53         488.22    637.45  3426.36         466.56
# ..      ...          ...            ...       ...      ...            ...
# 95    59.87        52.16         137.56    165.95  1667.65         101.02
# 96   210.02       382.05         632.69  1,081.98  3673.45         503.21
# 97   105.50       408.63         626.54  1,023.19  5408.03         800.22
# 98    82.86       250.15         374.44    362.32  2130.94         168.85
# 99   490.45     1,014.17        1597.36    927.13  1940.29         924.61
#
#     prop_crime  arson
# 0      5453.83  22.94
# 1      5415.82  20.93
# 2      2329.61    NaN
# 3      1385.85  12.39
# 4      4530.37  19.26
# ..         ...    ...
# 95     1934.62  11.22
# 96     5258.64  20.66
# 97     7231.44  23.03
# 98     2662.11   3.91
# 99     3792.04  52.59
#
# [100 rows x 14 columns]

# %% [markdown]
# ### Concat all 4 datasets into 1

# %%
crime_combined_df = pd.DataFrame()

# %%
crime_df_list = ['crime_40_60_df', 'crime_60_100_df', 'crime_100_250_df', 'crime_250_plus_df']

# %%
crime_combined_df = pd.concat([crime_40_60_df, crime_60_100_df, crime_100_250_df, crime_250_plus_df])
crime_combined_df = crime_combined_df.reset_index()
crime_combined_df
# Out:
#      index        states                                cities population  \
# 0        0  Pennsylvania  Abington Township, Montgomery County     55,731
# 1        1        Oregon                                Albany     51,084
# 2        2     Louisiana                            Alexandria     48,449
# 3        3    California                           Aliso Viejo     48,999
# 4        4       Florida                     Altamonte Springs     42,296
# ..     ...           ...                                   ...        ...
# 970     95      Virginia                        Virginia Beach    454,353
# 971     96    Washington                               Seattle    721,365
# 972     97    Washington                               Spokane    217,066
# 973     98     Wisconsin                               Madison    255,850
# 974     99     Wisconsin                             Milwaukee    595,168
#
#      violent_crime murder    rape  robbery agrv_assault  prop_crime  burglary  \
# 0           197.40    1.8    14.4    70.00        111.2     1979.10     296.1
# 1            86.10    0.0    19.6    45.00         21.5     3092.90     438.5
# 2          1682.20   18.6    28.9   293.10       1341.6     7492.40    2010.4
# 3            87.80    0.0     0.0    12.20         75.5      847.00     208.2
# 4           335.70    2.4    21.3    82.80        229.3     3057.00     427.9
# ..             ...    ...     ...      ...          ...         ...       ...
# 970         137.56   3.08   22.45    59.87        52.16     1934.62    165.95
# 971         632.69   3.74   36.87   210.02       382.05     5258.64  1,081.98
# 972         626.54   2.76  109.64   105.50       408.63     7231.44  1,023.19
# 973         374.44    4.3   37.13    82.86       250.15     2662.11    362.32
# 974        1597.36  19.83   72.92   490.45     1,014.17     3792.04    927.13
#
#      larceny  vehicle_theft  total_crime  arson
# 0    1650.80          32.30          NaN    NaN
# 1    2470.40         184.00          NaN    NaN
# 2    5102.30         379.80          NaN    NaN
# 3     612.30          26.50          NaN    NaN
# 4    2463.60         165.50          NaN    NaN
# ..       ...            ...          ...    ...
# 970  1667.65         101.02      2083.40  11.22
# 971  3673.45         503.21      5911.99  20.66
# 972  5408.03         800.22      7881.01  23.03
# 973  2130.94         168.85      3040.46   3.91
# 974  1940.29         924.61      5441.99  52.59
#
# [975 rows x 15 columns]

# %%
state_list_revised_1 = []
cities_list_revised_1 = []
for i,j in zip(crime_combined_df['states'], crime_combined_df['cities']):
    state_list_revised_1.append(remove_nums_from_string(i))
    cities_list_revised_1.append(remove_nums_from_string(j))
crime_combined_df['states'] = state_list_revised_1
crime_combined_df['cities'] = cities_list_revised_1
crime_combined_df
# Out:
#      index        states                                cities population  \
# 0        0  Pennsylvania  Abington Township, Montgomery County     55,731
# 1        1        Oregon                                Albany     51,084
# 2        2     Louisiana                            Alexandria     48,449
# 3        3    California                           Aliso Viejo     48,999
# 4        4       Florida                     Altamonte Springs     42,296
# ..     ...           ...                                   ...        ...
# 970     95      Virginia                        Virginia Beach    454,353
# 971     96    Washington                               Seattle    721,365
# 972     97    Washington                               Spokane    217,066
# 973     98     Wisconsin                               Madison    255,850
# 974     99     Wisconsin                             Milwaukee    595,168
#
#      violent_crime murder    rape  robbery agrv_assault  prop_crime  burglary  \
# 0           197.40    1.8    14.4    70.00        111.2     1979.10     296.1
# 1            86.10    0.0    19.6    45.00         21.5     3092.90     438.5
# 2          1682.20   18.6    28.9   293.10       1341.6     7492.40    2010.4
# 3            87.80    0.0     0.0    12.20         75.5      847.00     208.2
# 4           335.70    2.4    21.3    82.80        229.3     3057.00     427.9
# ..             ...    ...     ...      ...          ...         ...       ...
# 970         137.56   3.08   22.45    59.87        52.16     1934.62    165.95
# 971         632.69   3.74   36.87   210.02       382.05     5258.64  1,081.98
# 972         626.54   2.76  109.64   105.50       408.63     7231.44  1,023.19
# 973         374.44    4.3   37.13    82.86       250.15     2662.11    362.32
# 974        1597.36  19.83   72.92   490.45     1,014.17     3792.04    927.13
#
#      larceny  vehicle_theft  total_crime  arson
# 0    1650.80          32.30          NaN    NaN
# 1    2470.40         184.00          NaN    NaN
# 2    5102.30         379.80          NaN    NaN
# 3     612.30          26.50          NaN    NaN
# 4    2463.60         165.50          NaN    NaN
# ..       ...            ...          ...    ...
# 970  1667.65         101.02      2083.40  11.22
# 971  3673.45         503.21      5911.99  20.66
# 972  5408.03         800.22      7881.01  23.03
# 973  2130.94         168.85      3040.46   3.91
# 974  1940.29         924.61      5441.99  52.59
#
# [975 rows x 15 columns]

# %%
crime_combined_df['states'].unique()
# Out:
# array(['Pennsylvania', 'Oregon', 'Louisiana', 'California', 'Florida',
#        'Iowa', 'Indiana', 'Minnesota', 'Massachusetts', 'Alabama',
#        'Illinois', 'Tennessee', 'Ohio', 'Texas', 'Nebraska',
#        'Mississippi', 'New York', 'Virginia', 'Michigan', 'New Jersey',
#        'Missouri', 'Utah', 'Maryland', 'Kentucky', 'Colorado', 'Arizona',
#        'North Carolina', 'Idaho', 'Wyoming', 'New Hampshire', 'Georgia',
#        'Connecticut', 'Rhode Island', 'Washington', 'Oklahoma',
#        'New Mexico', 'Wisconsin', 'North Dakota', 'Montana', 'Kansas',
#        'Arkansas', 'South Carolina', 'Maine', 'South Dakota', 'Nevada',
#        'Delaware', '\xa0Alabama', '\xa0Alaska', '\xa0Arizona',
#        '\xa0California', '\xa0Colorado', '\xa0District of Columbia',
#        '\xa0Florida', '\xa0Georgia', '\xa0Hawaii', '\xa0Idaho',
#        '\xa0Illinois', '\xa0Indiana', '\xa0Iowa', '\xa0Kansas',
#        '\xa0Kentucky', '\xa0Louisiana', '\xa0Maryland',
#        '\xa0Massachusetts', '\xa0Michigan', '\xa0Minnesota',
#        '\xa0Missouri', '\xa0Nebraska', '\xa0Nevada', '\xa0New Jersey',
#        '\xa0New Mexico', '\xa0New York', '\xa0North Carolina', '\xa0Ohio',
#        '\xa0Oklahoma', '\xa0Oregon', '\xa0Pennsylvania', '\xa0Tennessee',
#        '\xa0Texas', '\xa0Virginia', '\xa0Washington', '\xa0Wisconsin'],
#       dtype=object)

# %% [markdown]
# ### remove '\xa0' from string; leave only state name

# %%
state_df = []
for i in crime_combined_df['states']:
    if '\xa0' in i:
        state_df.append(i.replace('\xa0', ''))
    else:
        state_df.append(i)
state_df = [state.upper() for state in state_df]
state_df
# Out:
# ['PENNSYLVANIA',
#  'OREGON',
#  'LOUISIANA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'PENNSYLVANIA',
#  'IOWA',
#  'INDIANA',
#  'IOWA',
#  'FLORIDA',
#  'MINNESOTA',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'MASSACHUSETTS',
#  'ALABAMA',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'ILLINOIS',
#  'TENNESSEE',
#  'OHIO',
#  'TEXAS',
#  'CALIFORNIA',
#  'NEBRASKA',
#  'ILLINOIS',
#  'MASSACHUSETTS',
#  'MASSACHUSETTS',
#  'MISSISSIPPI',
#  'NEW YORK',
#  'VIRGINIA',
#  'MINNESOTA',
#  'MICHIGAN',
#  'NEW JERSEY',
#  'MISSOURI',
#  'OHIO',
#  'UTAH',
#  'MARYLAND',
#  'KENTUCKY',
#  'FLORIDA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'PENNSYLVANIA',
#  'MASSACHUSETTS',
#  'COLORADO',
#  'ARIZONA',
#  'ILLINOIS',
#  'ARIZONA',
#  'NORTH CAROLINA',
#  'IDAHO',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'ARIZONA',
#  'WYOMING',
#  'COLORADO',
#  'CALIFORNIA',
#  'TEXAS',
#  'TEXAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'NORTH CAROLINA',
#  'VIRGINIA',
#  'MICHIGAN',
#  'MISSOURI',
#  'MASSACHUSETTS',
#  'OHIO',
#  'TENNESSEE',
#  'CALIFORNIA',
#  'FLORIDA',
#  'IDAHO',
#  'OHIO',
#  'TENNESSEE',
#  'CALIFORNIA',
#  'INDIANA',
#  'COLORADO',
#  'NEW HAMPSHIRE',
#  'TEXAS',
#  'TEXAS',
#  'FLORIDA',
#  'OREGON',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'OHIO',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'VIRGINIA',
#  'ILLINOIS',
#  'MICHIGAN',
#  'ALABAMA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'TEXAS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'ILLINOIS',
#  'UTAH',
#  'CALIFORNIA',
#  'OHIO',
#  'IOWA',
#  'GEORGIA',
#  'NEW JERSEY',
#  'CONNECTICUT',
#  'MICHIGAN',
#  'RHODE ISLAND',
#  'CALIFORNIA',
#  'MINNESOTA',
#  'WASHINGTON',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'CONNECTICUT',
#  'OKLAHOMA',
#  'TEXAS',
#  'MASSACHUSETTS',
#  'NEW JERSEY',
#  'OHIO',
#  'NEW MEXICO',
#  'MASSACHUSETTS',
#  'MISSOURI',
#  'WISCONSIN',
#  'FLORIDA',
#  'CALIFORNIA',
#  'NEW YORK',
#  'TEXAS',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'NORTH DAKOTA',
#  'NEBRASKA',
#  'COLORADO',
#  'TEXAS',
#  'MONTANA',
#  'NEW YORK',
#  'INDIANA',
#  'NEW JERSEY',
#  'MARYLAND',
#  'TEXAS',
#  'NEW YORK',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'VIRGINIA',
#  'MISSISSIPPI',
#  'PENNSYLVANIA',
#  'NEW YORK',
#  'TENNESSEE',
#  'NORTH CAROLINA',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'ILLINOIS',
#  'MASSACHUSETTS',
#  'NEW JERSEY',
#  'NORTH CAROLINA',
#  'CALIFORNIA',
#  'KANSAS',
#  'IDAHO',
#  'NEW YORK',
#  'NEW JERSEY',
#  'NEW JERSEY',
#  'MISSOURI',
#  'INDIANA',
#  'MISSOURI',
#  'FLORIDA',
#  'NEW JERSEY',
#  'TEXAS',
#  'OHIO',
#  'TENNESSEE',
#  'WASHINGTON',
#  'INDIANA',
#  'WISCONSIN',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'ARIZONA',
#  'MINNESOTA',
#  'OHIO',
#  'WASHINGTON',
#  'VIRGINIA',
#  'UTAH',
#  'KANSAS',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'COLORADO',
#  'UTAH',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'PENNSYLVANIA',
#  'ALABAMA',
#  'NEW JERSEY',
#  'CONNECTICUT',
#  'OHIO',
#  'TEXAS',
#  'FLORIDA',
#  'ARIZONA',
#  'GEORGIA',
#  'NEW JERSEY',
#  'OHIO',
#  'MISSISSIPPI',
#  'MASSACHUSETTS',
#  'OHIO',
#  'PENNSYLVANIA',
#  'CONNECTICUT',
#  'OHIO',
#  'MICHIGAN',
#  'OKLAHOMA',
#  'CONNECTICUT',
#  'PENNSYLVANIA',
#  'MINNESOTA',
#  'NORTH DAKOTA',
#  'INDIANA',
#  'ILLINOIS',
#  'LOUISIANA',
#  'OKLAHOMA',
#  'NEW JERSEY',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'OHIO',
#  'NEW YORK',
#  'ILLINOIS',
#  'NEW JERSEY',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'CONNECTICUT',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'ILLINOIS',
#  'FLORIDA',
#  'FLORIDA',
#  'WASHINGTON',
#  'ILLINOIS',
#  'ARIZONA',
#  'KENTUCKY',
#  'FLORIDA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'COLORADO',
#  'NEW JERSEY',
#  'MASSACHUSETTS',
#  'PENNSYLVANIA',
#  'FLORIDA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'TEXAS',
#  'ARKANSAS',
#  'FLORIDA',
#  'NEW JERSEY',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'IDAHO',
#  'TEXAS',
#  'FLORIDA',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'NEW YORK',
#  'CALIFORNIA',
#  'ARIZONA',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'WASHINGTON',
#  'MASSACHUSETTS',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'NORTH CAROLINA',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'NEW MEXICO',
#  'TEXAS',
#  'MICHIGAN',
#  'MICHIGAN',
#  'MICHIGAN',
#  'MASSACHUSETTS',
#  'KANSAS',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'NEW JERSEY',
#  'WISCONSIN',
#  'CONNECTICUT',
#  'WASHINGTON',
#  'ARIZONA',
#  'GEORGIA',
#  'TENNESSEE',
#  'NEW JERSEY',
#  'UTAH',
#  'NEW YORK',
#  'MISSISSIPPI',
#  'CONNECTICUT',
#  'MICHIGAN',
#  'MINNESOTA',
#  'MISSOURI',
#  'PENNSYLVANIA',
#  'OKLAHOMA',
#  'CONNECTICUT',
#  'ILLINOIS',
#  'OHIO',
#  'SOUTH CAROLINA',
#  'SOUTH CAROLINA',
#  'MASSACHUSETTS',
#  'NEW JERSEY',
#  'TEXAS',
#  'OREGON',
#  'ILLINOIS',
#  'FLORIDA',
#  'NEW YORK',
#  'NEW YORK',
#  'IDAHO',
#  'OHIO',
#  'NEW JERSEY',
#  'ILLINOIS',
#  'IOWA',
#  'GEORGIA',
#  'CONNECTICUT',
#  'OHIO',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'WISCONSIN',
#  'NEW JERSEY',
#  'NEW YORK',
#  'FLORIDA',
#  'OHIO',
#  'IOWA',
#  'CONNECTICUT',
#  'NEW JERSEY',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'NEW YORK',
#  'MASSACHUSETTS',
#  'MASSACHUSETTS',
#  'ILLINOIS',
#  'NEW YORK',
#  'PENNSYLVANIA',
#  'NORTH CAROLINA',
#  'CALIFORNIA',
#  'RHODE ISLAND',
#  'TEXAS',
#  'PENNSYLVANIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'GEORGIA',
#  'NEW YORK',
#  'CALIFORNIA',
#  'TEXAS',
#  'GEORGIA',
#  'CALIFORNIA',
#  'WISCONSIN',
#  'ILLINOIS',
#  'NORTH CAROLINA',
#  'WASHINGTON',
#  'ARIZONA',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'TEXAS',
#  'OREGON',
#  'CALIFORNIA',
#  'WASHINGTON',
#  'PENNSYLVANIA',
#  'PENNSYLVANIA',
#  'NORTH DAKOTA',
#  'ILLINOIS',
#  'INDIANA',
#  'MINNESOTA',
#  'FLORIDA',
#  'ILLINOIS',
#  'LOUISIANA',
#  'FLORIDA',
#  'NEW JERSEY',
#  'CONNECTICUT',
#  'MASSACHUSETTS',
#  'MINNESOTA',
#  'TEXAS',
#  'CALIFORNIA',
#  'MINNESOTA',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'OHIO',
#  'INDIANA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'NEW YORK',
#  'NEW JERSEY',
#  'WYOMING',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'NEW YORK',
#  'NEW JERSEY',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'TEXAS',
#  'NEW YORK',
#  'CALIFORNIA',
#  'ARKANSAS',
#  'MINNESOTA',
#  'IOWA',
#  'RHODE ISLAND',
#  'CONNECTICUT',
#  'FLORIDA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'MICHIGAN',
#  'ILLINOIS',
#  'FLORIDA',
#  'FLORIDA',
#  'ALABAMA',
#  'MINNESOTA',
#  'MINNESOTA',
#  'NEW JERSEY',
#  'MINNESOTA',
#  'TEXAS',
#  'OKLAHOMA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'CONNECTICUT',
#  'MASSACHUSETTS',
#  'MICHIGAN',
#  'ARKANSAS',
#  'WASHINGTON',
#  'INDIANA',
#  'ARIZONA',
#  'TEXAS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'ARKANSAS',
#  'MASSACHUSETTS',
#  'NEW JERSEY',
#  'TENNESSEE',
#  'MARYLAND',
#  'INDIANA',
#  'NORTH CAROLINA',
#  'NEW JERSEY',
#  'ARIZONA',
#  'NEW YORK',
#  'COLORADO',
#  'NORTH CAROLINA',
#  'SOUTH CAROLINA',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'NEW JERSEY',
#  'OHIO',
#  'INDIANA',
#  'TEXAS',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'OREGON',
#  'FLORIDA',
#  'ALABAMA',
#  'CALIFORNIA',
#  'IOWA',
#  'TENNESSEE',
#  'WISCONSIN',
#  'GEORGIA',
#  'TENNESSEE',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'LOUISIANA',
#  'WASHINGTON',
#  'WISCONSIN',
#  'FLORIDA',
#  'CALIFORNIA',
#  'INDIANA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'FLORIDA',
#  'NEW MEXICO',
#  'FLORIDA',
#  'KANSAS',
#  'MASSACHUSETTS',
#  'OKLAHOMA',
#  'UTAH',
#  'TEXAS',
#  'MISSOURI',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'COLORADO',
#  'TEXAS',
#  'OHIO',
#  'COLORADO',
#  'VIRGINIA',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'GEORGIA',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'MINNESOTA',
#  'WASHINGTON',
#  'OREGON',
#  'FLORIDA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CONNECTICUT',
#  'IDAHO',
#  'FLORIDA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'MONTANA',
#  'TEXAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'SOUTH CAROLINA',
#  'NEW YORK',
#  'CALIFORNIA',
#  'INDIANA',
#  'IDAHO',
#  'CALIFORNIA',
#  'NEW HAMPSHIRE',
#  'MASSACHUSETTS',
#  'TEXAS',
#  'CONNECTICUT',
#  'NEW YORK',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'NEW JERSEY',
#  'ARKANSAS',
#  'FLORIDA',
#  'TEXAS',
#  'PENNSYLVANIA',
#  'CONNECTICUT',
#  'MISSOURI',
#  'UTAH',
#  'NEW JERSEY',
#  'UTAH',
#  'WISCONSIN',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'OHIO',
#  'WASHINGTON',
#  'NEW JERSEY',
#  'RHODE ISLAND',
#  'TEXAS',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'MINNESOTA',
#  'MAINE',
#  'VIRGINIA',
#  'MASSACHUSETTS',
#  'WISCONSIN',
#  'NEW YORK',
#  'CALIFORNIA',
#  'SOUTH DAKOTA',
#  'PENNSYLVANIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'WASHINGTON',
#  'NEW MEXICO',
#  'VIRGINIA',
#  'SOUTH CAROLINA',
#  'GEORGIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'GEORGIA',
#  'UTAH',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'NEW MEXICO',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'NEW YORK',
#  'PENNSYLVANIA',
#  'KANSAS',
#  'MICHIGAN',
#  'IOWA',
#  'ILLINOIS',
#  'MASSACHUSETTS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'NEVADA',
#  'WASHINGTON',
#  'ARKANSAS',
#  'OHIO',
#  'OREGON',
#  'MISSOURI',
#  'UTAH',
#  'MISSOURI',
#  'TEXAS',
#  'FLORIDA',
#  'FLORIDA',
#  'MICHIGAN',
#  'TEXAS',
#  'INDIANA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'ALABAMA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'NEW YORK',
#  'CALIFORNIA',
#  'TEXAS',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'GEORGIA',
#  'RHODE ISLAND',
#  'MICHIGAN',
#  'IOWA',
#  'ILLINOIS',
#  'WISCONSIN',
#  'WISCONSIN',
#  'MICHIGAN',
#  'CONNECTICUT',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'DELAWARE',
#  'MINNESOTA',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'OHIO',
#  'CALIFORNIA',
#  'ARIZONA',
#  'TEXAS',
#  'OHIO',
#  'VIRGINIA',
#  'PENNSYLVANIA',
#  'TEXAS',
#  'NEW YORK',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'COLORADO',
#  'GEORGIA',
#  'ILLINOIS',
#  'LOUISIANA',
#  'TEXAS',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'MONTANA',
#  'ALABAMA',
#  'IDAHO',
#  'COLORADO',
#  'CONNECTICUT',
#  'OKLAHOMA',
#  'TEXAS',
#  'CALIFORNIA',
#  'MASSACHUSETTS',
#  'FLORIDA',
#  'CALIFORNIA',
#  'TEXAS',
#  'NORTH CAROLINA',
#  'IOWA',
#  'COLORADO',
#  'ARIZONA',
#  'SOUTH CAROLINA',
#  'VIRGINIA',
#  'CALIFORNIA',
#  'TENNESSEE',
#  'FLORIDA',
#  'MISSOURI',
#  'GEORGIA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'IOWA',
#  'OHIO',
#  'TEXAS',
#  'IOWA',
#  'CALIFORNIA',
#  'NORTH CAROLINA',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'NEW JERSEY',
#  'CALIFORNIA',
#  'PENNSYLVANIA',
#  'CALIFORNIA',
#  'OREGON',
#  'INDIANA',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'NORTH DAKOTA',
#  'NORTH CAROLINA',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'COLORADO',
#  'FLORIDA',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'TEXAS',
#  'ARIZONA',
#  'ARIZONA',
#  'CALIFORNIA',
#  'TEXAS',
#  'MICHIGAN',
#  'WISCONSIN',
#  'OREGON',
#  'VIRGINIA',
#  'CONNECTICUT',
#  'CALIFORNIA',
#  'FLORIDA',
#  'NORTH CAROLINA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'ALABAMA',
#  'MISSOURI',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'MISSISSIPPI',
#  'ILLINOIS',
#  'KANSAS',
#  'WASHINGTON',
#  'TEXAS',
#  'TENNESSEE',
#  'LOUISIANA',
#  'COLORADO',
#  'CALIFORNIA',
#  'MICHIGAN',
#  'TEXAS',
#  'ARKANSAS',
#  'MASSACHUSETTS',
#  'TEXAS',
#  'WISCONSIN',
#  'NEW HAMPSHIRE',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'FLORIDA',
#  'TEXAS',
#  'FLORIDA',
#  'CALIFORNIA',
#  'ALABAMA',
#  'CALIFORNIA',
#  'TENNESSEE',
#  'CALIFORNIA',
#  'ILLINOIS',
#  'CONNECTICUT',
#  'VIRGINIA',
#  'VIRGINIA',
#  'OKLAHOMA',
#  'SOUTH CAROLINA',
#  'NEVADA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'KANSAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'FLORIDA',
#  'KANSAS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'NEW JERSEY',
#  'FLORIDA',
#  'ARIZONA',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'FLORIDA',
#  'FLORIDA',
#  'RHODE ISLAND',
#  'UTAH',
#  'COLORADO',
#  'CALIFORNIA',
#  'NEVADA',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'VIRGINIA',
#  'MINNESOTA',
#  'NEW YORK',
#  'ILLINOIS',
#  'CALIFORNIA',
#  'TEXAS',
#  'OREGON',
#  'CALIFORNIA',
#  'UTAH',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'GEORGIA',
#  'ARIZONA',
#  'LOUISIANA',
#  'CALIFORNIA',
#  'SOUTH DAKOTA',
#  'INDIANA',
#  'WASHINGTON',
#  'ILLINOIS',
#  'MASSACHUSETTS',
#  'MISSOURI',
#  'FLORIDA',
#  'CONNECTICUT',
#  'MICHIGAN',
#  'CALIFORNIA',
#  'ARIZONA',
#  'NEW YORK',
#  'WASHINGTON',
#  'FLORIDA',
#  'CALIFORNIA',
#  'ARIZONA',
#  'COLORADO',
#  'CALIFORNIA',
#  'KANSAS',
#  'CALIFORNIA',
#  'TEXAS',
#  'CALIFORNIA',
#  'WASHINGTON',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'TEXAS',
#  'MICHIGAN',
#  'CONNECTICUT',
#  'CALIFORNIA',
#  'UTAH',
#  'FLORIDA',
#  'UTAH',
#  'COLORADO',
#  'TEXAS',
#  'NORTH CAROLINA',
#  'NORTH CAROLINA',
#  'NEW JERSEY',
#  'MASSACHUSETTS',
#  'NEW YORK',
#  'ALABAMA',
#  'ALASKA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'DISTRICT OF COLUMBIA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'GEORGIA',
#  'GEORGIA',
#  'HAWAII',
#  'IDAHO',
#  'ILLINOIS',
#  'INDIANA',
#  'INDIANA',
#  'IOWA',
#  'KANSAS',
#  'KENTUCKY',
#  'KENTUCKY',
#  'LOUISIANA',
#  'LOUISIANA',
#  'MARYLAND',
#  'MASSACHUSETTS',
#  'MICHIGAN',
#  'MINNESOTA',
#  'MINNESOTA',
#  'MISSOURI',
#  'MISSOURI',
#  'NEBRASKA',
#  'NEVADA',
#  'NEVADA',
#  'NEVADA',
#  'NEVADA',
#  'NEW JERSEY',
#  'NEW JERSEY',
#  'NEW MEXICO',
#  'NEW YORK',
#  'NEW YORK',
#  'NORTH CAROLINA',
#  'NORTH CAROLINA',
#  'NORTH CAROLINA',
#  'OHIO',
#  'OHIO',
#  'OHIO',
#  'OHIO',
#  'OKLAHOMA',
#  'OKLAHOMA',
#  'OREGON',
#  'PENNSYLVANIA',
#  'PENNSYLVANIA',
#  'TENNESSEE',
#  'TENNESSEE',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'TEXAS',
#  'VIRGINIA',
#  'VIRGINIA',
#  'VIRGINIA',
#  'WASHINGTON',
#  'WASHINGTON',
#  'WISCONSIN',
#  'WISCONSIN']

# %% [markdown]
# ### Change state name to its corresponding abbreviation

# %%
state_abbrev = [us_state_dictionary[key] for key in state_df]
state_abbrev
# Out:
# ['PA',
#  'OR',
#  'LA',
#  'CA',
#  'FL',
#  'PA',
#  'IA',
#  'IN',
#  'IA',
#  'FL',
#  'MN',
#  'CA',
#  'MA',
#  'MA',
#  'AL',
#  'CA',
#  'MA',
#  'IL',
#  'TN',
#  'OH',
#  'TX',
#  'CA',
#  'NE',
#  'IL',
#  'MA',
#  'MA',
#  'MS',
#  'NY',
#  'VA',
#  'MN',
#  'MI',
#  'NJ',
#  'MO',
#  'OH',
#  'UT',
#  'MD',
#  'KY',
#  'FL',
#  'CA',
#  'CA',
#  'NJ',
#  'PA',
#  'MA',
#  'CO',
#  'AZ',
#  'IL',
#  'AZ',
#  'NC',
#  'ID',
#  'CA',
#  'IL',
#  'AZ',
#  'WY',
#  'CO',
#  'CA',
#  'TX',
#  'TX',
#  'CA',
#  'CA',
#  'NC',
#  'VA',
#  'MI',
#  'MO',
#  'MA',
#  'OH',
#  'TN',
#  'CA',
#  'FL',
#  'ID',
#  'OH',
#  'TN',
#  'CA',
#  'IN',
#  'CO',
#  'NH',
#  'TX',
#  'TX',
#  'FL',
#  'OR',
#  'CA',
#  'IL',
#  'CA',
#  'FL',
#  'OH',
#  'CA',
#  'CA',
#  'VA',
#  'IL',
#  'MI',
#  'AL',
#  'CA',
#  'IL',
#  'TX',
#  'CA',
#  'FL',
#  'IL',
#  'UT',
#  'CA',
#  'OH',
#  'IA',
#  'GA',
#  'NJ',
#  'CT',
#  'MI',
#  'RI',
#  'CA',
#  'MN',
#  'WA',
#  'NJ',
#  'CA',
#  'IL',
#  'CT',
#  'OK',
#  'TX',
#  'MA',
#  'NJ',
#  'OH',
#  'NM',
#  'MA',
#  'MO',
#  'WI',
#  'FL',
#  'CA',
#  'NY',
#  'TX',
#  'CA',
#  'TX',
#  'CA',
#  'CA',
#  'IL',
#  'ND',
#  'NE',
#  'CO',
#  'TX',
#  'MT',
#  'NY',
#  'IN',
#  'NJ',
#  'MD',
#  'TX',
#  'NY',
#  'CA',
#  'PA',
#  'VA',
#  'MS',
#  'PA',
#  'NY',
#  'TN',
#  'NC',
#  'CA',
#  'NJ',
#  'IL',
#  'MA',
#  'NJ',
#  'NC',
#  'CA',
#  'KS',
#  'ID',
#  'NY',
#  'NJ',
#  'NJ',
#  'MO',
#  'IN',
#  'MO',
#  'FL',
#  'NJ',
#  'TX',
#  'OH',
#  'TN',
#  'WA',
#  'IN',
#  'WI',
#  'CA',
#  'CA',
#  'CA',
#  'WA',
#  'CA',
#  'AZ',
#  'MN',
#  'OH',
#  'WA',
#  'VA',
#  'UT',
#  'KS',
#  'MA',
#  'CA',
#  'NJ',
#  'CO',
#  'UT',
#  'IL',
#  'CA',
#  'PA',
#  'PA',
#  'AL',
#  'NJ',
#  'CT',
#  'OH',
#  'TX',
#  'FL',
#  'AZ',
#  'GA',
#  'NJ',
#  'OH',
#  'MS',
#  'MA',
#  'OH',
#  'PA',
#  'CT',
#  'OH',
#  'MI',
#  'OK',
#  'CT',
#  'PA',
#  'MN',
#  'ND',
#  'IN',
#  'IL',
#  'LA',
#  'OK',
#  'NJ',
#  'IL',
#  'CA',
#  'NJ',
#  'CA',
#  'OH',
#  'NY',
#  'IL',
#  'NJ',
#  'FL',
#  'FL',
#  'FL',
#  'CT',
#  'CA',
#  'MI',
#  'IL',
#  'FL',
#  'FL',
#  'WA',
#  'IL',
#  'AZ',
#  'KY',
#  'FL',
#  'CA',
#  'CA',
#  'CA',
#  'CO',
#  'NJ',
#  'MA',
#  'PA',
#  'FL',
#  'NJ',
#  'CA',
#  'TX',
#  'AR',
#  'FL',
#  'NJ',
#  'MA',
#  'CA',
#  'NJ',
#  'ID',
#  'TX',
#  'FL',
#  'MI',
#  'CA',
#  'NY',
#  'CA',
#  'AZ',
#  'IL',
#  'CA',
#  'CA',
#  'WA',
#  'MA',
#  'WA',
#  'CA',
#  'NC',
#  'AR',
#  'CA',
#  'CA',
#  'MI',
#  'NM',
#  'TX',
#  'MI',
#  'MI',
#  'MI',
#  'MA',
#  'KS',
#  'WA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'TX',
#  'CA',
#  'FL',
#  'CA',
#  'FL',
#  'NJ',
#  'WI',
#  'CT',
#  'WA',
#  'AZ',
#  'GA',
#  'TN',
#  'NJ',
#  'UT',
#  'NY',
#  'MS',
#  'CT',
#  'MI',
#  'MN',
#  'MO',
#  'PA',
#  'OK',
#  'CT',
#  'IL',
#  'OH',
#  'SC',
#  'SC',
#  'MA',
#  'NJ',
#  'TX',
#  'OR',
#  'IL',
#  'FL',
#  'NY',
#  'NY',
#  'ID',
#  'OH',
#  'NJ',
#  'IL',
#  'IA',
#  'GA',
#  'CT',
#  'OH',
#  'NJ',
#  'CA',
#  'WI',
#  'NJ',
#  'NY',
#  'FL',
#  'OH',
#  'IA',
#  'CT',
#  'NJ',
#  'NJ',
#  'CA',
#  'NY',
#  'MA',
#  'MA',
#  'IL',
#  'NY',
#  'PA',
#  'NC',
#  'CA',
#  'RI',
#  'TX',
#  'PA',
#  'CA',
#  'CA',
#  'GA',
#  'NY',
#  'CA',
#  'TX',
#  'GA',
#  'CA',
#  'WI',
#  'IL',
#  'NC',
#  'WA',
#  'AZ',
#  'CA',
#  'NJ',
#  'TX',
#  'OR',
#  'CA',
#  'WA',
#  'PA',
#  'PA',
#  'ND',
#  'IL',
#  'IN',
#  'MN',
#  'FL',
#  'IL',
#  'LA',
#  'FL',
#  'NJ',
#  'CT',
#  'MA',
#  'MN',
#  'TX',
#  'CA',
#  'MN',
#  'CA',
#  'NJ',
#  'OH',
#  'IN',
#  'CA',
#  'IL',
#  'NY',
#  'NJ',
#  'WY',
#  'CA',
#  'CA',
#  'CA',
#  'IL',
#  'CA',
#  'NY',
#  'NJ',
#  'MI',
#  'CA',
#  'TX',
#  'NY',
#  'CA',
#  'AR',
#  'MN',
#  'IA',
#  'RI',
#  'CT',
#  'FL',
#  'CA',
#  'FL',
#  'MI',
#  'IL',
#  'FL',
#  'FL',
#  'AL',
#  'MN',
#  'MN',
#  'NJ',
#  'MN',
#  'TX',
#  'OK',
#  'CA',
#  'IL',
#  'CT',
#  'MA',
#  'MI',
#  'AR',
#  'WA',
#  'IN',
#  'AZ',
#  'TX',
#  'CA',
#  'FL',
#  'AR',
#  'MA',
#  'NJ',
#  'TN',
#  'MD',
#  'IN',
#  'NC',
#  'NJ',
#  'AZ',
#  'NY',
#  'CO',
#  'NC',
#  'SC',
#  'CT',
#  'CT',
#  'NJ',
#  'OH',
#  'IN',
#  'TX',
#  'MA',
#  'CA',
#  'CA',
#  'CA',
#  'OR',
#  'FL',
#  'AL',
#  'CA',
#  'IA',
#  'TN',
#  'WI',
#  'GA',
#  'TN',
#  'AR',
#  'CA',
#  'MI',
#  'LA',
#  'WA',
#  'WI',
#  'FL',
#  'CA',
#  'IN',
#  'CA',
#  'CA',
#  'FL',
#  'NJ',
#  'CA',
#  'PA',
#  'FL',
#  'NM',
#  'FL',
#  'KS',
#  'MA',
#  'OK',
#  'UT',
#  'TX',
#  'MO',
#  'CA',
#  'MI',
#  'CA',
#  'CO',
#  'TX',
#  'OH',
#  'CO',
#  'VA',
#  'MA',
#  'CA',
#  'GA',
#  'CA',
#  'MA',
#  'CA',
#  'MN',
#  'WA',
#  'OR',
#  'FL',
#  'CA',
#  'CA',
#  'CT',
#  'ID',
#  'FL',
#  'NJ',
#  'CA',
#  'CA',
#  'TX',
#  'MT',
#  'TX',
#  'CA',
#  'CA',
#  'SC',
#  'NY',
#  'CA',
#  'IN',
#  'ID',
#  'CA',
#  'NH',
#  'MA',
#  'TX',
#  'CT',
#  'NY',
#  'CA',
#  'MA',
#  'NJ',
#  'AR',
#  'FL',
#  'TX',
#  'PA',
#  'CT',
#  'MO',
#  'UT',
#  'NJ',
#  'UT',
#  'WI',
#  'IL',
#  'CA',
#  'OH',
#  'WA',
#  'NJ',
#  'RI',
#  'TX',
#  'CA',
#  'TX',
#  'CA',
#  'CA',
#  'FL',
#  'CA',
#  'MN',
#  'ME',
#  'VA',
#  'MA',
#  'WI',
#  'NY',
#  'CA',
#  'SD',
#  'PA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'WA',
#  'NM',
#  'VA',
#  'SC',
#  'GA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'GA',
#  'UT',
#  'CA',
#  'CA',
#  'NM',
#  'CA',
#  'IL',
#  'NY',
#  'PA',
#  'KS',
#  'MI',
#  'IA',
#  'IL',
#  'MA',
#  'CA',
#  'CA',
#  'MI',
#  'NV',
#  'WA',
#  'AR',
#  'OH',
#  'OR',
#  'MO',
#  'UT',
#  'MO',
#  'TX',
#  'FL',
#  'FL',
#  'MI',
#  'TX',
#  'IN',
#  'NJ',
#  'CA',
#  'NJ',
#  'MI',
#  'CA',
#  'CA',
#  'AL',
#  'CA',
#  'CA',
#  'NJ',
#  'CA',
#  'PA',
#  'NY',
#  'CA',
#  'TX',
#  'NJ',
#  'CA',
#  'CA',
#  'MA',
#  'GA',
#  'RI',
#  'MI',
#  'IA',
#  'IL',
#  'WI',
#  'WI',
#  'MI',
#  'CT',
#  'MI',
#  'CA',
#  'FL',
#  'CA',
#  'DE',
#  'MN',
#  'WA',
#  'CA',
#  'PA',
#  'OH',
#  'CA',
#  'AZ',
#  'TX',
#  'OH',
#  'VA',
#  'PA',
#  'TX',
#  'NY',
#  'MI',
#  'CA',
#  'CO',
#  'GA',
#  'IL',
#  'LA',
#  'TX',
#  'WA',
#  'CA',
#  'MT',
#  'AL',
#  'ID',
#  'CO',
#  'CT',
#  'OK',
#  'TX',
#  'CA',
#  'MA',
#  'FL',
#  'CA',
#  'TX',
#  'NC',
#  'IA',
#  'CO',
#  'AZ',
#  'SC',
#  'VA',
#  'CA',
#  'TN',
#  'FL',
#  'MO',
#  'GA',
#  'CA',
#  'FL',
#  'CA',
#  'CA',
#  'CA',
#  'IA',
#  'OH',
#  'TX',
#  'IA',
#  'CA',
#  'NC',
#  'NJ',
#  'CA',
#  'CA',
#  'IL',
#  'NJ',
#  'CA',
#  'PA',
#  'CA',
#  'OR',
#  'IN',
#  'WA',
#  'CA',
#  'ND',
#  'NC',
#  'MI',
#  'CA',
#  'CO',
#  'FL',
#  'CA',
#  'TX',
#  'CA',
#  'FL',
#  'CA',
#  'TX',
#  'AZ',
#  'AZ',
#  'CA',
#  'TX',
#  'MI',
#  'WI',
#  'OR',
#  'VA',
#  'CT',
#  'CA',
#  'FL',
#  'NC',
#  'FL',
#  'CA',
#  'AL',
#  'MO',
#  'CA',
#  'CA',
#  'TX',
#  'MS',
#  'IL',
#  'KS',
#  'WA',
#  'TX',
#  'TN',
#  'LA',
#  'CO',
#  'CA',
#  'MI',
#  'TX',
#  'AR',
#  'MA',
#  'TX',
#  'WI',
#  'NH',
#  'TX',
#  'TX',
#  'TX',
#  'FL',
#  'TX',
#  'FL',
#  'CA',
#  'AL',
#  'CA',
#  'TN',
#  'CA',
#  'IL',
#  'CT',
#  'VA',
#  'VA',
#  'OK',
#  'SC',
#  'NV',
#  'CA',
#  'CA',
#  'TX',
#  'KS',
#  'CA',
#  'CA',
#  'FL',
#  'KS',
#  'CA',
#  'FL',
#  'CA',
#  'CA',
#  'TX',
#  'NJ',
#  'FL',
#  'AZ',
#  'IL',
#  'CA',
#  'FL',
#  'FL',
#  'RI',
#  'UT',
#  'CO',
#  'CA',
#  'NV',
#  'CA',
#  'TX',
#  'CA',
#  'VA',
#  'MN',
#  'NY',
#  'IL',
#  'CA',
#  'TX',
#  'OR',
#  'CA',
#  'UT',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'GA',
#  'AZ',
#  'LA',
#  'CA',
#  'SD',
#  'IN',
#  'WA',
#  'IL',
#  'MA',
#  'MO',
#  'FL',
#  'CT',
#  'MI',
#  'CA',
#  'AZ',
#  'NY',
#  'WA',
#  'FL',
#  'CA',
#  'AZ',
#  'CO',
#  'CA',
#  'KS',
#  'CA',
#  'TX',
#  'CA',
#  'WA',
#  'CA',
#  'CA',
#  'CA',
#  'TX',
#  'MI',
#  'CT',
#  'CA',
#  'UT',
#  'FL',
#  'UT',
#  'CO',
#  'TX',
#  'NC',
#  'NC',
#  'NJ',
#  'MA',
#  'NY',
#  'AL',
#  'AK',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CA',
#  'CO',
#  'CO',
#  'CO',
#  'DC',
#  'FL',
#  'FL',
#  'FL',
#  'FL',
#  'FL',
#  'FL',
#  'GA',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'KY',
#  'LA',
#  'LA',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MN',
#  'MO',
#  'MO',
#  'NE',
#  'NV',
#  'NV',
#  'NV',
#  'NV',
#  'NJ',
#  'NJ',
#  'NM',
#  'NY',
#  'NY',
#  'NC',
#  'NC',
#  'NC',
#  'OH',
#  'OH',
#  'OH',
#  'OH',
#  'OK',
#  'OK',
#  'OR',
#  'PA',
#  'PA',
#  'TN',
#  'TN',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'VA',
#  'VA',
#  'VA',
#  'WA',
#  'WA',
#  'WI',
#  'WI']

# %%
crime_combined_df['states'] = state_abbrev
crime_combined_df
# Out:
#      index states                                cities population  \
# 0        0     PA  Abington Township, Montgomery County     55,731
# 1        1     OR                                Albany     51,084
# 2        2     LA                            Alexandria     48,449
# 3        3     CA                           Aliso Viejo     48,999
# 4        4     FL                     Altamonte Springs     42,296
# ..     ...    ...                                   ...        ...
# 970     95     VA                        Virginia Beach    454,353
# 971     96     WA                               Seattle    721,365
# 972     97     WA                               Spokane    217,066
# 973     98     WI                               Madison    255,850
# 974     99     WI                             Milwaukee    595,168
#
#      violent_crime murder    rape  robbery agrv_assault  prop_crime  burglary  \
# 0           197.40    1.8    14.4    70.00        111.2     1979.10     296.1
# 1            86.10    0.0    19.6    45.00         21.5     3092.90     438.5
# 2          1682.20   18.6    28.9   293.10       1341.6     7492.40    2010.4
# 3            87.80    0.0     0.0    12.20         75.5      847.00     208.2
# 4           335.70    2.4    21.3    82.80        229.3     3057.00     427.9
# ..             ...    ...     ...      ...          ...         ...       ...
# 970         137.56   3.08   22.45    59.87        52.16     1934.62    165.95
# 971         632.69   3.74   36.87   210.02       382.05     5258.64  1,081.98
# 972         626.54   2.76  109.64   105.50       408.63     7231.44  1,023.19
# 973         374.44    4.3   37.13    82.86       250.15     2662.11    362.32
# 974        1597.36  19.83   72.92   490.45     1,014.17     3792.04    927.13
#
#      larceny  vehicle_theft  total_crime  arson
# 0    1650.80          32.30          NaN    NaN
# 1    2470.40         184.00          NaN    NaN
# 2    5102.30         379.80          NaN    NaN
# 3     612.30          26.50          NaN    NaN
# 4    2463.60         165.50          NaN    NaN
# ..       ...            ...          ...    ...
# 970  1667.65         101.02      2083.40  11.22
# 971  3673.45         503.21      5911.99  20.66
# 972  5408.03         800.22      7881.01  23.03
# 973  2130.94         168.85      3040.46   3.91
# 974  1940.29         924.61      5441.99  52.59
#
# [975 rows x 15 columns]

# %% [markdown]
# ### Upload housing dataset

# %%
cleaned_housing_data = pd.read_csv('cleaned_housing_data.csv')
cleaned_housing_data
# Out:
#       State        City       Street  Zipcode  Bedroom  Bathroom     Area  \
# 0        AL    Saraland     Scott Dr  36571.0      4.0       2.0   1614.0
# 1        AL    Saraland  Deer Run Dr  36571.0      3.0       2.0   1828.0
# 2        AL     Chelsea   Mallet Way  35043.0      3.0       3.0   2224.0
# 3        AL     Chelsea  Highway 440  35043.0      3.0       2.0   1425.0
# 4        AL  Montgomery  Brampton Ln  36117.0      3.0       2.0   1564.0
# ...     ...         ...          ...      ...      ...       ...      ...
# 12599    WY   Big Piney   Taylor Ave  83113.0      4.0       2.0   1820.0
# 12600    WY      Daniel     Booth Dr  83115.0      1.0       1.0   1008.0
# 12601    WY    Shoshoni      Pine St  82649.0      6.0       3.0   3294.0
# 12602    WY       Mills    N 4th Ave  82604.0      4.0       2.0   2120.0
# 12603    WY     Bedford      Deer Rd  83112.0      7.0       6.0  10041.0
#
#              PPSq  LotArea  MarketEstimate  ...  military  incorporated  \
# 0      148.636927   0.3805        240600.0  ...     False          True
# 1      108.315098   0.4658        199700.0  ...     False          True
# 2      150.629496   0.2600        336200.0  ...     False          True
# 3      195.789474   1.8200        280200.0  ...     False          True
# 4       96.547315   0.2000        150500.0  ...     False          True
# ...           ...      ...             ...  ...       ...           ...
# 12599  112.637363   0.1600        189800.0  ...     False          True
# 12600  337.202381  10.0600        307500.0  ...     False         False
# 12601   74.377656   0.3200        236800.0  ...     False          True
# 12602   90.094340   0.3100        184600.0  ...     False          True
# 12603  492.978787   5.0000       4781100.0  ...     False         False
#
#               timezone  ranking  \
# 0      America/Chicago        3
# 1      America/Chicago        3
# 2      America/Chicago        3
# 3      America/Chicago        3
# 4      America/Chicago        2
# ...                ...      ...
# 12599   America/Denver        3
# 12600   America/Denver        3
# 12601   America/Denver        3
# 12602   America/Denver        3
# 12603   America/Denver        3
#
#                                                     zips          id  \
# 0                                                  36571  1840015886
# 1                                                  36571  1840015886
# 2                                            35051 35043  1840014823
# 3                                            35051 35043  1840014823
# 4      36112 36113 36110 36111 36116 36114 36115 3610...  1840008353
# ...                                                  ...         ...
# 12599                                              83113  1840020061
# 12600                                              83115  1840018659
# 12601                                              82649  1840022355
# 12602                                  82644 82604 82601  1840022359
# 12603                                              83112  1840017451
#
#               house_coordinates  closest_city      city_coordinates  \
# 0        (30.819534, -88.09596)   New Orleans   (30.0687, -89.9288)
# 1        (30.841074, -88.08948)   New Orleans   (30.0687, -89.9288)
# 2         (33.357986, -86.6087)    Birmingham   (33.5279, -86.7971)
# 3        (33.354427, -86.59509)    Birmingham   (33.5279, -86.7971)
# 4       (32.372746, -86.165115)    Birmingham   (33.5279, -86.7971)
# ...                         ...           ...                   ...
# 12599  (42.552986, -110.113075)         Ogden  (41.2279, -111.9682)
# 12600   (42.975636, -110.32426)         Ogden  (41.2279, -111.9682)
# 12601    (43.23948, -108.11593)         Ogden  (41.2279, -111.9682)
# 12602   (42.851006, -106.39181)        Denver   (39.762, -104.8758)
# 12603  (42.920673, -110.921776)         Ogden  (41.2279, -111.9682)
#
#       distance_to_maj_city_miles
# 0                     121.001418
# 1                     121.980045
# 2                      15.987941
# 3                      16.708137
# 4                      87.664428
# ...                          ...
# 12599                 132.340884
# 12600                 147.269952
# 12601                 241.450936
# 12602                 227.287741
# 12603                 128.625419
#
# [12604 rows x 27 columns]

# %% [markdown]
# ### Read in crime dataset 2

# %%
# note values in fbi_crime_df are total number of certain crime reported in a city
fbi_crime_df = pd.read_excel(r"Table_8_Offenses_Known_to_Law_Enforcement_by_State_by_City_2019.xls")
fbi_crime_df = fbi_crime_df.drop([0,1])
fbi_crime_df = fbi_crime_df.reset_index(drop = True)
fbi_crime_df.columns = fbi_crime_df.iloc[0]
fbi_crime_df = fbi_crime_df[1:-8]
fbi_crime_df
# Out:
# 0        State                 City Population Violent\ncrime  \
# 1     ALABAMA3               Hoover      85670            114
# 2       ALASKA            Anchorage     287731           3581
# 3          NaN               Bethel       6544            130
# 4          NaN  Bristol Bay Borough        852              2
# 5          NaN              Cordova       2150              0
# ...        ...                  ...        ...            ...
# 8101       NaN             Sheridan      17895              9
# 8102       NaN         Thermopolis5       2830             13
# 8103       NaN           Torrington       6709             13
# 8104       NaN            Wheatland       3544              7
# 8105       NaN              Worland       5026              8
#
# 0    Murder and\nnonnegligent\nmanslaughter Rape1 Robbery Aggravated\nassault  \
# 1                                         4    15      27                  68
# 2                                        32   540     621                2388
# 3                                         1    47       3                  79
# 4                                         0     0       0                   2
# 5                                         0     0       0                   0
# ...                                     ...   ...     ...                 ...
# 8101                                      0     4       0                   5
# 8102                                      0     0       0                  13
# 8103                                      0     4       1                   8
# 8104                                      0     1       0                   6
# 8105                                      0     5       0                   3
#
# 0    Property\ncrime Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson2
# 1               1922      128            1694                   100      2
# 2              12261     1692            9038                  1531     93
# 3                132       20              84                    28     12
# 4                 20        5               8                     7      0
# 5                  7        1               6                     0      0
# ...              ...      ...             ...                   ...    ...
# 8101             369       75             278                    16      3
# 8102              34        7              22                     5      0
# 8103              48        8              40                     0      0
# 8104              72       24              45                     3      0
# 8105              36        6              30                     0      0
#
# [8105 rows x 13 columns]

# %%
fbi_crime_df.columns
# Out:
# Index(['State', 'City', 'Population', 'Violent\ncrime',
#        'Murder and\nnonnegligent\nmanslaughter', 'Rape1', 'Robbery',
#        'Aggravated\nassault', 'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson2'],
#       dtype='object', name=0)

# %%
fbi_crime_df['State']
# Out:
# 1       ALABAMA3
# 2         ALASKA
# 3            NaN
# 4            NaN
# 5            NaN
#           ...
# 8101         NaN
# 8102         NaN
# 8103         NaN
# 8104         NaN
# 8105         NaN
# Name: State, Length: 8105, dtype: object

# %% [markdown]
# ### Fill in state nan values with its actual corresponding state

# %%
state_list = []
current_state = 'ALABAMA'
for i in fbi_crime_df['State']:
    if pd.notna(i):
        current_state = i
    else:
        i = current_state
    state_list.append(i)
state_list
# Out:
# ['ALABAMA3',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DISTRICT OF COLUMBIA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  ...]

# %%
state_list_revised = []
for i in state_list:
    state_list_revised.append(remove_nums_from_string(i))
state_list_revised
# Out:
# ['ALABAMA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ALASKA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARIZONA',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'CALIFORNIA',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'COLORADO',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'CONNECTICUT',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DELAWARE',
#  'DISTRICT OF COLUMBIA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  'FLORIDA',
#  ...]

# %% [markdown]
# ### Replace state name with its corresponding abbreviation

# %%
state_list_revised_abreviation = [us_state_dictionary[key] for key in state_list_revised]
len(state_list_revised_abreviation)
# Out:
# 8105

# %%
fbi_crime_df['State'] = state_list_revised_abreviation
fbi_crime_df
# Out:
# 0    State                 City Population Violent\ncrime  \
# 1       AL               Hoover      85670            114
# 2       AK            Anchorage     287731           3581
# 3       AK               Bethel       6544            130
# 4       AK  Bristol Bay Borough        852              2
# 5       AK              Cordova       2150              0
# ...    ...                  ...        ...            ...
# 8101    WY             Sheridan      17895              9
# 8102    WY         Thermopolis5       2830             13
# 8103    WY           Torrington       6709             13
# 8104    WY            Wheatland       3544              7
# 8105    WY              Worland       5026              8
#
# 0    Murder and\nnonnegligent\nmanslaughter Rape1 Robbery Aggravated\nassault  \
# 1                                         4    15      27                  68
# 2                                        32   540     621                2388
# 3                                         1    47       3                  79
# 4                                         0     0       0                   2
# 5                                         0     0       0                   0
# ...                                     ...   ...     ...                 ...
# 8101                                      0     4       0                   5
# 8102                                      0     0       0                  13
# 8103                                      0     4       1                   8
# 8104                                      0     1       0                   6
# 8105                                      0     5       0                   3
#
# 0    Property\ncrime Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson2
# 1               1922      128            1694                   100      2
# 2              12261     1692            9038                  1531     93
# 3                132       20              84                    28     12
# 4                 20        5               8                     7      0
# 5                  7        1               6                     0      0
# ...              ...      ...             ...                   ...    ...
# 8101             369       75             278                    16      3
# 8102              34        7              22                     5      0
# 8103              48        8              40                     0      0
# 8104              72       24              45                     3      0
# 8105              36        6              30                     0      0
#
# [8105 rows x 13 columns]

# %%
crime_city_list = []
for i in fbi_crime_df['City']:
    crime_city_list.append(remove_nums_from_string(i))
crime_city_list
# Out:
# ['Hoover',
#  'Anchorage',
#  'Bethel',
#  'Bristol Bay Borough',
#  'Cordova',
#  'Craig',
#  'Dillingham',
#  'Fairbanks',
#  'Haines',
#  'Homer',
#  'Juneau',
#  'Kenai',
#  'Ketchikan',
#  'Kodiak',
#  'Kotzebue',
#  'Nome',
#  'North Pole',
#  'North Slope Borough',
#  'Palmer',
#  'Petersburg',
#  'Seward',
#  'Sitka',
#  'Skagway',
#  'Soldotna',
#  'Unalaska',
#  'Valdez',
#  'Wasilla',
#  'Wrangell',
#  'Apache Junction',
#  'Avondale',
#  'Buckeye',
#  'Bullhead City',
#  'Camp Verde',
#  'Casa Grande',
#  'Chandler',
#  'Chino Valley',
#  'Clarkdale',
#  'Coolidge',
#  'Cottonwood',
#  'Douglas',
#  'Eagar',
#  'El Mirage',
#  'Flagstaff',
#  'Florence',
#  'Fredonia',
#  'Gilbert',
#  'Glendale',
#  'Globe',
#  'Goodyear',
#  'Hayden',
#  'Holbrook',
#  'Huachuca City',
#  'Jerome',
#  'Kearny',
#  'Kingman',
#  'Lake Havasu City',
#  'Mammoth',
#  'Marana',
#  'Maricopa',
#  'Mesa',
#  'Miami',
#  'Nogales',
#  'Oro Valley',
#  'Page',
#  'Paradise Valley',
#  'Parker',
#  'Payson',
#  'Peoria',
#  'Phoenix',
#  'Pima',
#  'Pinetop-Lakeside',
#  'Prescott',
#  'Prescott Valley',
#  'Safford',
#  'Sahuarita',
#  'San Luis',
#  'Scottsdale',
#  'Show Low',
#  'Sierra Vista',
#  'Snowflake-Taylor',
#  'Somerton',
#  'Springerville',
#  'St. Johns',
#  'Surprise',
#  'Tempe',
#  'Thatcher',
#  'Tolleson',
#  'Tucson',
#  'Wellton',
#  'Wickenburg',
#  'Willcox',
#  'Williams',
#  'Winslow',
#  'Yuma',
#  'Alexander',
#  'Alma',
#  'Altus',
#  'Amity',
#  'Ashdown',
#  'Ash Flat',
#  'Atkins',
#  'Augusta',
#  'Austin',
#  'Bald Knob',
#  'Barling',
#  'Batesville',
#  'Bay',
#  'Bearden',
#  'Beebe',
#  'Bella Vista',
#  'Benton',
#  'Bentonville',
#  'Berryville',
#  'Bethel Heights',
#  'Blytheville',
#  'Bono',
#  'Booneville',
#  'Bradford',
#  'Brinkley',
#  'Brookland',
#  'Bryant',
#  'Bull Shoals',
#  'Cabot',
#  'Caddo Valley',
#  'Camden',
#  'Cammack Village',
#  'Carlisle',
#  'Cave Springs',
#  'Cedarville',
#  'Centerton',
#  'Charleston',
#  'Cherokee Village',
#  'Cherry Valley',
#  'Clarksville',
#  'Clinton',
#  'Conway',
#  'Corning',
#  'Cotter',
#  'Crossett',
#  'Damascus',
#  'Dardanelle',
#  'Decatur',
#  'De Queen',
#  'Des Arc',
#  'DeWitt',
#  'Diaz',
#  'Dover',
#  'Dumas',
#  'Earle',
#  'El Dorado',
#  'Elkins',
#  'England',
#  'Etowah',
#  'Eudora',
#  'Eureka Springs',
#  'Fairfield Bay',
#  'Farmington',
#  'Fayetteville',
#  'Flippin',
#  'Fordyce',
#  'Forrest City',
#  'Fort Smith',
#  'Gassville',
#  'Gentry',
#  'Glenwood',
#  'Gosnell',
#  'Gravette',
#  'Greenbrier',
#  'Green Forest',
#  'Greenland',
#  'Greenwood',
#  'Gurdon',
#  'Hamburg',
#  'Harrisburg',
#  'Harrison',
#  'Haskell',
#  'Hazen',
#  'Heber Springs',
#  'Helena-West Helena',
#  'Highland',
#  'Hope',
#  'Hot Springs',
#  'Hoxie',
#  'Jacksonville',
#  'Jericho',
#  'Johnson',
#  'Jonesboro',
#  'Judsonia',
#  'Kensett',
#  'Lake City',
#  'Lakeview',
#  'Lake Village',
#  'Lamar',
#  'Lincoln',
#  'Little Flock',
#  'Little Rock',
#  'Lonoke',
#  'Lowell',
#  'Luxora',
#  'Madison',
#  'Magnolia',
#  'Marianna',
#  'Marion',
#  'Marked Tree',
#  'Marmaduke',
#  'Marshall',
#  'Maumelle',
#  'Mayflower',
#  'McCrory',
#  'McGehee',
#  'McRae',
#  'Mena',
#  'Menifee',
#  'Mineral Springs',
#  'Monette',
#  'Monticello',
#  'Morrilton',
#  'Mountainburg',
#  'Mountain Home',
#  'Mountain View',
#  'Mulberry',
#  'Murfreesboro',
#  'Nashville',
#  'Newport',
#  'Norfork',
#  'North Little Rock',
#  'Osceola',
#  'Ozark',
#  'Paragould',
#  'Paris',
#  'Pea Ridge',
#  'Perryville',
#  'Piggott',
#  'Pine Bluff',
#  'Plumerville',
#  'Pocahontas',
#  'Pottsville',
#  'Prairie Grove',
#  'Prescott',
#  'Quitman',
#  'Ravenden',
#  'Redfield',
#  'Rogers',
#  'Rose Bud',
#  'Russellville',
#  'Salem',
#  'Searcy',
#  'Shannon Hills',
#  'Sheridan',
#  'Sherwood',
#  'Siloam Springs',
#  'Star City',
#  'St. Charles',
#  'Stuttgart',
#  'Sulphur Springs',
#  'Swifton',
#  'Texarkana',
#  'Trumann',
#  'Tuckerman',
#  'Van Buren',
#  'Vilonia',
#  'Waldron',
#  'Walnut Ridge',
#  'Ward',
#  'Warren',
#  'Weiner',
#  'West Fork',
#  'West Memphis',
#  'White Hall',
#  'Wilson',
#  'Wynne',
#  'Adelanto',
#  'Agoura Hills',
#  'Alameda',
#  'Albany',
#  'Alhambra',
#  'Aliso Viejo',
#  'Alturas',
#  'American Canyon',
#  'Anaheim',
#  'Anderson',
#  'Angels Camp',
#  'Antioch',
#  'Apple Valley',
#  'Arcadia',
#  'Arcata',
#  'Arroyo Grande',
#  'Artesia',
#  'Arvin',
#  'Atascadero',
#  'Atherton',
#  'Atwater',
#  'Auburn',
#  'Avalon',
#  'Avenal',
#  'Azusa',
#  'Bakersfield',
#  'Baldwin Park',
#  'Banning',
#  'Barstow',
#  'Bear Valley',
#  'Beaumont',
#  'Bell',
#  'Bellflower',
#  'Bell Gardens',
#  'Belmont',
#  'Belvedere',
#  'Benicia',
#  'Berkeley',
#  'Beverly Hills',
#  'Big Bear',
#  'Biggs',
#  'Bishop',
#  'Blythe',
#  'Bradbury',
#  'Brawley',
#  'Brea',
#  'Brentwood',
#  'Brisbane',
#  'Broadmoor',
#  'Buellton',
#  'Buena Park',
#  'Burbank',
#  'Burlingame',
#  'Calabasas',
#  'Calexico',
#  'California City',
#  'Calimesa',
#  'Calistoga',
#  'Camarillo',
#  'Campbell',
#  'Canyon Lake',
#  'Capitola',
#  'Carlsbad',
#  'Carmel',
#  'Carpinteria',
#  'Carson',
#  'Cathedral City',
#  'Central Marin',
#  'Ceres',
#  'Cerritos',
#  'Chico',
#  'Chino',
#  'Chino Hills',
#  'Chowchilla',
#  'Chula Vista',
#  'Citrus Heights',
#  'Claremont',
#  'Clayton',
#  'Clearlake',
#  'Cloverdale',
#  'Clovis',
#  'Coachella',
#  'Coalinga',
#  'Colma',
#  'Colton',
#  'Colusa',
#  'Commerce',
#  'Compton',
#  'Concord',
#  'Corcoran',
#  'Corning',
#  'Corona',
#  'Coronado',
#  'Costa Mesa',
#  'Cotati',
#  'Covina',
#  'Crescent City',
#  'Cudahy',
#  'Culver City',
#  'Cupertino',
#  'Cypress',
#  'Daly City',
#  'Dana Point',
#  'Danville',
#  'Davis',
#  'Delano',
#  'Del Mar',
#  'Del Rey Oaks',
#  'Desert Hot Springs',
#  'Diamond Bar',
#  'Dinuba',
#  'Dixon',
#  'Dorris',
#  'Dos Palos',
#  'Downey',
#  'Duarte',
#  'Dublin',
#  'Dunsmuir',
#  'East Palo Alto',
#  'Eastvale',
#  'El Cajon',
#  'El Centro',
#  'El Cerrito',
#  'Elk Grove',
#  'El Monte',
#  'El Segundo',
#  'Emeryville',
#  'Encinitas',
#  'Escalon',
#  'Escondido',
#  'Etna',
#  'Eureka',
#  'Exeter',
#  'Fairfax',
#  'Fairfield',
#  'Farmersville',
#  'Ferndale',
#  'Fillmore',
#  'Firebaugh',
#  'Folsom',
#  'Fontana',
#  'Fort Bragg',
#  'Fort Jones',
#  'Fortuna',
#  'Foster City',
#  'Fountain Valley',
#  'Fowler',
#  'Fremont',
#  'Fullerton',
#  'Galt',
#  'Gardena',
#  'Garden Grove',
#  'Gilroy',
#  'Glendale',
#  'Glendora',
#  'Goleta',
#  'Gonzales',
#  'Grand Terrace',
#  'Grass Valley',
#  'Greenfield',
#  'Gridley',
#  'Grover Beach',
#  'Guadalupe',
#  'Gustine',
#  'Hanford',
#  'Hawaiian Gardens',
#  'Hawthorne',
#  'Hayward',
#  'Healdsburg',
#  'Hemet',
#  'Hercules',
#  'Hermosa Beach',
#  'Hesperia',
#  'Hidden Hills',
#  'Highland',
#  'Hillsborough',
#  'Hollister',
#  'Holtville',
#  'Hughson',
#  'Huntington Beach',
#  'Huntington Park',
#  'Huron',
#  'Imperial',
#  'Imperial Beach',
#  'Indian Wells',
#  'Indio',
#  'Industry',
#  'Inglewood',
#  'Ione',
#  'Irvine',
#  'Irwindale',
#  'Isleton',
#  'Jackson',
#  'Jurupa Valley',
#  'Kensington',
#  'Kerman',
#  'King City',
#  'Kingsburg',
#  'La Canada Flintridge',
#  'Lafayette',
#  'Laguna Beach',
#  'Laguna Hills',
#  'Laguna Niguel',
#  'Laguna Woods',
#  'La Habra',
#  'La Habra Heights',
#  'Lake Elsinore',
#  'Lake Forest',
#  'Lakeport',
#  'Lake Shastina',
#  'Lakewood',
#  'La Mesa',
#  'La Mirada',
#  'Lancaster',
#  'La Palma',
#  'La Puente',
#  'La Quinta',
#  'La Verne',
#  'Lawndale',
#  'Lemon Grove',
#  'Lemoore',
#  'Lincoln',
#  'Lindsay',
#  'Livermore',
#  'Livingston',
#  'Lodi',
#  'Loma Linda',
#  'Lomita',
#  'Lompoc',
#  'Long Beach',
#  'Los Alamitos',
#  'Los Altos',
#  'Los Altos Hills',
#  'Los Angeles',
#  'Los Banos',
#  'Los Gatos',
#  'Lynwood',
#  'Madera',
#  'Malibu',
#  'Mammoth Lakes',
#  'Manhattan Beach',
#  'Manteca',
#  'Marina',
#  'Martinez',
#  'Marysville',
#  'Maywood',
#  'McFarland',
#  'Mendota',
#  'Menifee',
#  'Menlo Park',
#  'Merced',
#  'Mill Valley',
#  'Milpitas',
#  'Mission Viejo',
#  'Modesto',
#  'Monrovia',
#  'Montague',
#  'Montclair',
#  'Montebello',
#  'Monterey',
#  'Monterey Park',
#  'Monte Sereno',
#  'Moorpark',
#  'Moraga',
#  'Moreno Valley',
#  'Morgan Hill',
#  'Morro Bay',
#  'Mountain View',
#  'Mount Shasta',
#  'Murrieta',
#  'Napa',
#  'National City',
#  'Needles',
#  'Nevada City',
#  'Newark',
#  'Newman',
#  'Newport Beach',
#  'Norco',
#  'Norwalk',
#  'Novato',
#  'Oakdale',
#  'Oakland',
#  'Oakley',
#  'Oceanside',
#  'Ojai',
#  'Ontario',
#  'Orange',
#  'Orange Cove',
#  'Orinda',
#  'Orland',
#  'Oroville',
#  'Oxnard',
#  'Pacifica',
#  'Pacific Grove',
#  'Palmdale',
#  'Palm Desert',
#  'Palm Springs',
#  'Palo Alto',
#  'Palos Verdes Estates',
#  'Paradise',
#  'Paramount',
#  'Parlier',
#  'Pasadena',
#  'Paso Robles',
#  'Patterson',
#  'Perris',
#  'Petaluma',
#  'Pico Rivera',
#  'Piedmont',
#  'Pinole',
#  'Pismo Beach',
#  'Pittsburg',
#  'Placentia',
#  'Placerville',
#  'Pleasant Hill',
#  'Pleasanton',
#  'Pomona',
#  'Porterville',
#  'Port Hueneme',
#  'Poway',
#  'Rancho Cordova',
#  'Rancho Cucamonga',
#  'Rancho Mirage',
#  'Rancho Palos Verdes',
#  'Rancho Santa Margarita',
#  'Red Bluff',
#  'Redlands',
#  'Redondo Beach',
#  'Redwood City',
#  'Reedley',
#  'Rialto',
#  'Richmond',
#  'Ridgecrest',
#  'Rio Dell',
#  'Rio Vista',
#  'Ripon',
#  'Riverbank',
#  'Riverside',
#  'Rocklin',
#  'Rohnert Park',
#  'Rolling Hills',
#  'Rolling Hills Estates',
#  'Rosemead',
#  'Roseville',
#  'Ross',
#  'Sacramento',
#  'Salinas',
#  'San Bernardino',
#  'San Bruno',
#  'San Clemente',
#  'Sand City',
#  'San Diego',
#  'San Dimas',
#  'San Fernando',
#  'San Francisco',
#  'San Gabriel',
#  'Sanger',
#  'San Jacinto',
#  'San Jose',
#  'San Juan Capistrano',
#  'San Leandro',
#  'San Luis Obispo',
#  'San Marcos',
#  'San Marino',
#  'San Mateo',
#  'San Pablo',
#  'San Rafael',
#  'San Ramon',
#  'Santa Ana',
#  'Santa Barbara',
#  'Santa Clara',
#  'Santa Clarita',
#  'Santa Cruz',
#  'Santa Fe Springs',
#  'Santa Monica',
#  'Santa Paula',
#  'Santa Rosa',
#  'Santee',
#  'Saratoga',
#  'Sausalito',
#  'Scotts Valley',
#  'Seal Beach',
#  'Seaside',
#  'Sebastopol',
#  'Selma',
#  'Shafter',
#  'Sierra Madre',
#  'Signal Hill',
#  'Simi Valley',
#  'Solana Beach',
#  'Soledad',
#  'Solvang',
#  'Sonoma',
#  'Sonora',
#  'South El Monte',
#  'South Gate',
#  'South Lake Tahoe',
#  'South Pasadena',
#  'South San Francisco',
#  'Stallion Springs',
#  'Stanton',
#  'St. Helena',
#  'Stockton',
#  'Suisun City',
#  'Sunnyvale',
#  'Susanville',
#  'Sutter Creek',
#  'Taft',
#  'Tehachapi',
#  'Temecula',
#  'Temple City',
#  'Thousand Oaks',
#  'Tiburon',
#  'Torrance',
#  'Tracy',
#  'Truckee',
#  'Tulare',
#  'Tulelake',
#  'Turlock',
#  'Tustin',
#  'Twentynine Palms',
#  'Ukiah',
#  'Union City',
#  'Upland',
#  'Vacaville',
#  'Vallejo',
#  'Ventura',
#  'Vernon',
#  'Victorville',
#  'Villa Park',
#  'Visalia',
#  'Vista',
#  'Walnut',
#  'Walnut Creek',
#  'Waterford',
#  'Watsonville',
#  'Weed',
#  'West Covina',
#  'West Hollywood',
#  'Westlake Village',
#  'Westminster',
#  'West Sacramento',
#  'Wheatland',
#  'Whittier',
#  'Wildomar',
#  'Williams',
#  'Willits',
#  'Windsor',
#  'Winters',
#  'Woodlake',
#  'Woodland',
#  'Yorba Linda',
#  'Yountville',
#  'Yreka',
#  'Yuba City',
#  'Yucaipa',
#  'Yucca Valley',
#  'Alamosa',
#  'Arvada',
#  'Aspen',
#  'Aurora',
#  'Avon',
#  'Basalt',
#  'Bayfield',
#  'Black Hawk',
#  'Boulder',
#  'Bow Mar',
#  'Breckenridge',
#  'Brighton',
#  'Broomfield',
#  'Buena Vista',
#  'Burlington',
#  'Canon City',
#  'Carbondale',
#  'Castle Rock',
#  'Center',
#  'Cherry Hills Village',
#  'Colorado Springs',
#  'Columbine Valley',
#  'Commerce City',
#  'Cortez',
#  'Craig',
#  'Crested Butte',
#  'Cripple Creek',
#  'Dacono',
#  'Delta',
#  'Denver',
#  'Dillon',
#  'Durango',
#  'Eaton',
#  'Edgewater',
#  'Elizabeth',
#  'Englewood',
#  'Erie',
#  'Estes Park',
#  'Evans',
#  'Fairplay',
#  'Firestone',
#  'Florence',
#  'Fort Collins',
#  'Fort Morgan',
#  'Fountain',
#  'Fowler',
#  'Fraser/Winter Park',
#  'Frederick',
#  'Frisco',
#  'Fruita',
#  'Glendale',
#  'Glenwood Springs',
#  'Granby',
#  'Grand Junction',
#  'Greeley',
#  'Green Mountain Falls',
#  'Gunnison',
#  'Hayden',
#  'Holyoke',
#  'Hotchkiss',
#  'Hudson',
#  'Idaho Springs',
#  'Ignacio',
#  'Johnstown',
#  'Kersey',
#  'Lafayette',
#  'La Junta',
#  'Lakeside',
#  'Lamar',
#  'La Salle',
#  'Leadville',
#  'Limon',
#  'Littleton',
#  'Lone Tree',
#  'Longmont',
#  'Louisville',
#  'Loveland',
#  'Mancos',
#  'Manitou Springs',
#  'Mead',
#  'Meeker',
#  'Milliken',
#  'Monte Vista',
#  'Montrose',
#  'Mountain View',
#  'Mountain Village',
#  'Mount Crested Butte',
#  'Nederland',
#  'New Castle',
#  'Northglenn',
#  'Oak Creek',
#  'Olathe',
#  'Pagosa Springs',
#  'Palisade',
#  'Parachute',
#  'Parker',
#  'Platteville',
#  'Pueblo',
#  'Rangely',
#  'Rifle',
#  'Salida',
#  'Severance',
#  'Sheridan',
#  'Silt',
#  'Silverthorne',
#  'Simla',
#  'Snowmass Village',
#  'South Fork',
#  'Springfield',
#  'Sterling',
#  'Telluride',
#  'Thornton',
#  'Timnath',
#  'Trinidad',
#  'Walsh',
#  'Westminster',
#  'Woodland Park',
#  'Wray',
#  'Yuma',
#  'Ansonia',
#  'Avon',
#  'Berlin',
#  'Bethel',
#  'Bloomfield',
#  'Branford',
#  'Bridgeport',
#  'Bristol',
#  'Brookfield',
#  'Canton',
#  'Cheshire',
#  'Clinton',
#  'Coventry',
#  'Cromwell',
#  'Danbury',
#  'Darien',
#  'Derby',
#  'East Hampton',
#  'East Hartford',
#  'East Haven',
#  'East Lyme',
#  'Easton',
#  'East Windsor',
#  'Enfield',
#  'Fairfield',
#  'Farmington',
#  'Glastonbury',
#  'Granby',
#  'Greenwich',
#  'Groton',
#  'Groton Long Point',
#  'Groton Town',
#  'Guilford',
#  'Hamden',
#  'Hartford',
#  'Ledyard',
#  'Madison',
#  'Manchester',
#  'Meriden',
#  'Middlebury',
#  'Middletown',
#  'Milford',
#  'Monroe',
#  'Naugatuck',
#  'New Britain',
#  'New Canaan',
#  'New Haven',
#  'Newington',
#  'New London',
#  'New Milford',
#  'Newtown',
#  'North Branford',
#  'North Haven',
#  'Norwalk',
#  'Norwich',
#  'Old Saybrook',
#  'Orange',
#  'Plainfield',
#  'Plainville',
#  'Plymouth',
#  'Portland',
#  'Putnam',
#  'Redding',
#  'Ridgefield',
#  'Rocky Hill',
#  'Seymour',
#  'Shelton',
#  'Simsbury',
#  'Southington',
#  'South Windsor',
#  'Stamford',
#  'Stonington',
#  'Stratford',
#  'Suffield',
#  'Thomaston',
#  'Torrington',
#  'Trumbull',
#  'Vernon',
#  'Wallingford',
#  'Waterbury',
#  'Waterford',
#  'Watertown',
#  'West Hartford',
#  'West Haven',
#  'Weston',
#  'Westport',
#  'Wethersfield',
#  'Willimantic',
#  'Wilton',
#  'Winchester',
#  'Windsor',
#  'Windsor Locks',
#  'Wolcott',
#  'Woodbridge',
#  'Bethany Beach',
#  'Blades',
#  'Bridgeville',
#  'Camden',
#  'Cheswold',
#  'Clayton',
#  'Dagsboro',
#  'Delaware City',
#  'Delmar',
#  'Dewey Beach',
#  'Dover',
#  'Ellendale',
#  'Elsmere',
#  'Felton',
#  'Georgetown',
#  'Greenwood',
#  'Harrington',
#  'Laurel',
#  'Lewes',
#  'Middletown',
#  'Milford',
#  'Millsboro',
#  'Milton',
#  'Newark',
#  'New Castle',
#  'Newport',
#  'Ocean View',
#  'Rehoboth Beach',
#  'Seaford',
#  'Selbyville',
#  'Smyrna',
#  'Wilmington',
#  'Wyoming',
#  'Washington',
#  'Alachua',
#  'Altamonte Springs',
#  'Altha',
#  'Apopka',
#  'Arcadia',
#  'Astatula',
#  'Atlantic Beach',
#  'Atlantis',
#  'Auburndale',
#  'Aventura',
#  'Bal Harbour Village',
#  'Bartow',
#  'Bay Harbor Islands',
#  'Belleair',
#  'Belleair Beach',
#  'Belleair Bluffs',
#  'Belle Glade',
#  'Belle Isle',
#  'Belleview',
#  'Biscayne Park',
#  'Blountstown',
#  'Boca Raton',
#  'Bonifay',
#  'Bowling Green',
#  'Boynton Beach',
#  ...]

# %%
fbi_crime_df['City'] = crime_city_list
fbi_crime_df
# Out:
# 0    State                 City Population Violent\ncrime  \
# 1       AL               Hoover      85670            114
# 2       AK            Anchorage     287731           3581
# 3       AK               Bethel       6544            130
# 4       AK  Bristol Bay Borough        852              2
# 5       AK              Cordova       2150              0
# ...    ...                  ...        ...            ...
# 8101    WY             Sheridan      17895              9
# 8102    WY          Thermopolis       2830             13
# 8103    WY           Torrington       6709             13
# 8104    WY            Wheatland       3544              7
# 8105    WY              Worland       5026              8
#
# 0    Murder and\nnonnegligent\nmanslaughter Rape1 Robbery Aggravated\nassault  \
# 1                                         4    15      27                  68
# 2                                        32   540     621                2388
# 3                                         1    47       3                  79
# 4                                         0     0       0                   2
# 5                                         0     0       0                   0
# ...                                     ...   ...     ...                 ...
# 8101                                      0     4       0                   5
# 8102                                      0     0       0                  13
# 8103                                      0     4       1                   8
# 8104                                      0     1       0                   6
# 8105                                      0     5       0                   3
#
# 0    Property\ncrime Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson2
# 1               1922      128            1694                   100      2
# 2              12261     1692            9038                  1531     93
# 3                132       20              84                    28     12
# 4                 20        5               8                     7      0
# 5                  7        1               6                     0      0
# ...              ...      ...             ...                   ...    ...
# 8101             369       75             278                    16      3
# 8102              34        7              22                     5      0
# 8103              48        8              40                     0      0
# 8104              72       24              45                     3      0
# 8105              36        6              30                     0      0
#
# [8105 rows x 13 columns]

# %% [markdown]
# ### Subset crime dataset 1 to contain only certain columns

# %%
# just keep violent crime and property crime
crime_combined_df_revised = crime_combined_df[['states', 'cities', 'population', 'violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']]
crime_combined_df_revised = crime_combined_df_revised.dropna()
crime_combined_df_revised.rename(columns = {'states': 'State', 'cities': 'City'}, inplace=True)
crime_combined_df_revised
# Out:
#     State                                  City population  violent_crime  \
# 0      PA  Abington Township, Montgomery County     55,731         197.40
# 1      OR                                Albany     51,084          86.10
# 2      LA                            Alexandria     48,449        1682.20
# 3      CA                           Aliso Viejo     48,999          87.80
# 4      FL                     Altamonte Springs     42,296         335.70
# ..    ...                                   ...        ...            ...
# 970    VA                        Virginia Beach    454,353         137.56
# 971    WA                               Seattle    721,365         632.69
# 972    WA                               Spokane    217,066         626.54
# 973    WI                               Madison    255,850         374.44
# 974    WI                             Milwaukee    595,168        1597.36
#
#      prop_crime  larceny  vehicle_theft
# 0       1979.10  1650.80          32.30
# 1       3092.90  2470.40         184.00
# 2       7492.40  5102.30         379.80
# 3        847.00   612.30          26.50
# 4       3057.00  2463.60         165.50
# ..          ...      ...            ...
# 970     1934.62  1667.65         101.02
# 971     5258.64  3673.45         503.21
# 972     7231.44  5408.03         800.22
# 973     2662.11  2130.94         168.85
# 974     3792.04  1940.29         924.61
#
# [950 rows x 7 columns]

# %%
crime_combined_df_revised['population'] = crime_combined_df_revised['population'].str.replace(',', '')
crime_combined_df_revised['population'] = crime_combined_df_revised['population'].astype(float)
crime_combined_df_revised = crime_combined_df_revised.reset_index(drop = True)
crime_combined_df_revised
# Out:
#     State                                  City  population  violent_crime  \
# 0      PA  Abington Township, Montgomery County     55731.0         197.40
# 1      OR                                Albany     51084.0          86.10
# 2      LA                            Alexandria     48449.0        1682.20
# 3      CA                           Aliso Viejo     48999.0          87.80
# 4      FL                     Altamonte Springs     42296.0         335.70
# ..    ...                                   ...         ...            ...
# 945    VA                        Virginia Beach    454353.0         137.56
# 946    WA                               Seattle    721365.0         632.69
# 947    WA                               Spokane    217066.0         626.54
# 948    WI                               Madison    255850.0         374.44
# 949    WI                             Milwaukee    595168.0        1597.36
#
#      prop_crime  larceny  vehicle_theft
# 0       1979.10  1650.80          32.30
# 1       3092.90  2470.40         184.00
# 2       7492.40  5102.30         379.80
# 3        847.00   612.30          26.50
# 4       3057.00  2463.60         165.50
# ..          ...      ...            ...
# 945     1934.62  1667.65         101.02
# 946     5258.64  3673.45         503.21
# 947     7231.44  5408.03         800.22
# 948     2662.11  2130.94         168.85
# 949     3792.04  1940.29         924.61
#
# [950 rows x 7 columns]

# %% [markdown]
# #### Normalize all crimes by the total population in each city (i.e. per capita)

# %%
for i in range(crime_combined_df_revised.shape[0]):
    for j in ['violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']:
        crime_combined_df_revised[j][i] = crime_combined_df_revised[j].iloc[i] / crime_combined_df_revised['population'].iloc[i]
crime_combined_df_revised
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_20732\1355395394.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_combined_df_revised[j][i] = crime_combined_df_revised[j].iloc[i] / crime_combined_df_revised['population'].iloc[i]
#     State                                  City  population  violent_crime  \
# 0      PA  Abington Township, Montgomery County     55731.0       0.003542
# 1      OR                                Albany     51084.0       0.001685
# 2      LA                            Alexandria     48449.0       0.034721
# 3      CA                           Aliso Viejo     48999.0       0.001792
# 4      FL                     Altamonte Springs     42296.0       0.007937
# ..    ...                                   ...         ...            ...
# 945    VA                        Virginia Beach    454353.0       0.000303
# 946    WA                               Seattle    721365.0       0.000877
# 947    WA                               Spokane    217066.0       0.002886
# 948    WI                               Madison    255850.0       0.001464
# 949    WI                             Milwaukee    595168.0       0.002684
#
#      prop_crime   larceny  vehicle_theft
# 0      0.035512  0.029621       0.000580
# 1      0.060545  0.048360       0.003602
# 2      0.154645  0.105313       0.007839
# 3      0.017286  0.012496       0.000541
# 4      0.072276  0.058247       0.003913
# ..          ...       ...            ...
# 945    0.004258  0.003670       0.000222
# 946    0.007290  0.005092       0.000698
# 947    0.033314  0.024914       0.003687
# 948    0.010405  0.008329       0.000660
# 949    0.006371  0.003260       0.001554
#
# [950 rows x 7 columns]

# %%
fbi_crime_df_revised = fbi_crime_df[['State', 'City', 'Population', 'Violent\ncrime', 'Property\ncrime', 'Larceny-\ntheft', 'Motor\nvehicle\ntheft']]
fbi_crime_df_revised
# Out:
# 0    State                 City Population Violent\ncrime Property\ncrime  \
# 1       AL               Hoover      85670            114            1922
# 2       AK            Anchorage     287731           3581           12261
# 3       AK               Bethel       6544            130             132
# 4       AK  Bristol Bay Borough        852              2              20
# 5       AK              Cordova       2150              0               7
# ...    ...                  ...        ...            ...             ...
# 8101    WY             Sheridan      17895              9             369
# 8102    WY          Thermopolis       2830             13              34
# 8103    WY           Torrington       6709             13              48
# 8104    WY            Wheatland       3544              7              72
# 8105    WY              Worland       5026              8              36
#
# 0    Larceny-\ntheft Motor\nvehicle\ntheft
# 1               1694                   100
# 2               9038                  1531
# 3                 84                    28
# 4                  8                     7
# 5                  6                     0
# ...              ...                   ...
# 8101             278                    16
# 8102              22                     5
# 8103              40                     0
# 8104              45                     3
# 8105              30                     0
#
# [8105 rows x 7 columns]

# %%
fbi_rename_map = {
    'State':'State', 
    'City':'City', 
    'Population':'population', 
    'Violent\ncrime':'violent_crime', 
    'Property\ncrime':'prop_crime', 
    'Larceny-\ntheft':'larceny', 
    'Motor\nvehicle\ntheft':'vehicle_theft'
}

# %%
fbi_crime_df_revised.rename(columns = fbi_rename_map, inplace=True)
fbi_crime_df_revised = fbi_crime_df_revised.dropna()
fbi_crime_df_revised = fbi_crime_df_revised.reset_index(drop = True)
fbi_crime_df_revised
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_20732\2981303520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbi_crime_df_revised.rename(columns = fbi_rename_map, inplace=True)
# 0    State                 City population violent_crime prop_crime larceny  \
# 0       AL               Hoover      85670           114       1922    1694
# 1       AK            Anchorage     287731          3581      12261    9038
# 2       AK               Bethel       6544           130        132      84
# 3       AK  Bristol Bay Borough        852             2         20       8
# 4       AK              Cordova       2150             0          7       6
# ...    ...                  ...        ...           ...        ...     ...
# 8054    WY             Sheridan      17895             9        369     278
# 8055    WY          Thermopolis       2830            13         34      22
# 8056    WY           Torrington       6709            13         48      40
# 8057    WY            Wheatland       3544             7         72      45
# 8058    WY              Worland       5026             8         36      30
#
# 0    vehicle_theft
# 0              100
# 1             1531
# 2               28
# 3                7
# 4                0
# ...            ...
# 8054            16
# 8055             5
# 8056             0
# 8057             3
# 8058             0
#
# [8059 rows x 7 columns]

# %%
for i in range(fbi_crime_df_revised.shape[0]):
    for j in ['violent_crime', 'prop_crime', 'larceny', 'vehicle_theft']:
        fbi_crime_df_revised[j][i] = fbi_crime_df_revised[j].iloc[i] / fbi_crime_df_revised['population'].iloc[i]
fbi_crime_df_revised
# Out:
# 0    State                 City population violent_crime prop_crime   larceny  \
# 0       AL               Hoover      85670      0.001331   0.022435  0.019774
# 1       AK            Anchorage     287731      0.012446   0.042613  0.031411
# 2       AK               Bethel       6544      0.019866   0.020171  0.012836
# 3       AK  Bristol Bay Borough        852      0.002347   0.023474   0.00939
# 4       AK              Cordova       2150           0.0   0.003256  0.002791
# ...    ...                  ...        ...           ...        ...       ...
# 8054    WY             Sheridan      17895      0.000503    0.02062  0.015535
# 8055    WY          Thermopolis       2830      0.004594   0.012014  0.007774
# 8056    WY           Torrington       6709      0.001938   0.007155  0.005962
# 8057    WY            Wheatland       3544      0.001975   0.020316  0.012698
# 8058    WY              Worland       5026      0.001592   0.007163  0.005969
#
# 0    vehicle_theft
# 0         0.001167
# 1         0.005321
# 2         0.004279
# 3         0.008216
# 4              0.0
# ...            ...
# 8054      0.000894
# 8055      0.001767
# 8056           0.0
# 8057      0.000847
# 8058           0.0
#
# [8059 rows x 7 columns]

# %%
cleaned_housing_data
# Out:
#       State        City       Street  Zipcode  Bedroom  Bathroom     Area  \
# 0        AL    Saraland     Scott Dr  36571.0      4.0       2.0   1614.0
# 1        AL    Saraland  Deer Run Dr  36571.0      3.0       2.0   1828.0
# 2        AL     Chelsea   Mallet Way  35043.0      3.0       3.0   2224.0
# 3        AL     Chelsea  Highway 440  35043.0      3.0       2.0   1425.0
# 4        AL  Montgomery  Brampton Ln  36117.0      3.0       2.0   1564.0
# ...     ...         ...          ...      ...      ...       ...      ...
# 12599    WY   Big Piney   Taylor Ave  83113.0      4.0       2.0   1820.0
# 12600    WY      Daniel     Booth Dr  83115.0      1.0       1.0   1008.0
# 12601    WY    Shoshoni      Pine St  82649.0      6.0       3.0   3294.0
# 12602    WY       Mills    N 4th Ave  82604.0      4.0       2.0   2120.0
# 12603    WY     Bedford      Deer Rd  83112.0      7.0       6.0  10041.0
#
#              PPSq  LotArea  MarketEstimate  ...  military  incorporated  \
# 0      148.636927   0.3805        240600.0  ...     False          True
# 1      108.315098   0.4658        199700.0  ...     False          True
# 2      150.629496   0.2600        336200.0  ...     False          True
# 3      195.789474   1.8200        280200.0  ...     False          True
# 4       96.547315   0.2000        150500.0  ...     False          True
# ...           ...      ...             ...  ...       ...           ...
# 12599  112.637363   0.1600        189800.0  ...     False          True
# 12600  337.202381  10.0600        307500.0  ...     False         False
# 12601   74.377656   0.3200        236800.0  ...     False          True
# 12602   90.094340   0.3100        184600.0  ...     False          True
# 12603  492.978787   5.0000       4781100.0  ...     False         False
#
#               timezone  ranking  \
# 0      America/Chicago        3
# 1      America/Chicago        3
# 2      America/Chicago        3
# 3      America/Chicago        3
# 4      America/Chicago        2
# ...                ...      ...
# 12599   America/Denver        3
# 12600   America/Denver        3
# 12601   America/Denver        3
# 12602   America/Denver        3
# 12603   America/Denver        3
#
#                                                     zips          id  \
# 0                                                  36571  1840015886
# 1                                                  36571  1840015886
# 2                                            35051 35043  1840014823
# 3                                            35051 35043  1840014823
# 4      36112 36113 36110 36111 36116 36114 36115 3610...  1840008353
# ...                                                  ...         ...
# 12599                                              83113  1840020061
# 12600                                              83115  1840018659
# 12601                                              82649  1840022355
# 12602                                  82644 82604 82601  1840022359
# 12603                                              83112  1840017451
#
#               house_coordinates  closest_city      city_coordinates  \
# 0        (30.819534, -88.09596)   New Orleans   (30.0687, -89.9288)
# 1        (30.841074, -88.08948)   New Orleans   (30.0687, -89.9288)
# 2         (33.357986, -86.6087)    Birmingham   (33.5279, -86.7971)
# 3        (33.354427, -86.59509)    Birmingham   (33.5279, -86.7971)
# 4       (32.372746, -86.165115)    Birmingham   (33.5279, -86.7971)
# ...                         ...           ...                   ...
# 12599  (42.552986, -110.113075)         Ogden  (41.2279, -111.9682)
# 12600   (42.975636, -110.32426)         Ogden  (41.2279, -111.9682)
# 12601    (43.23948, -108.11593)         Ogden  (41.2279, -111.9682)
# 12602   (42.851006, -106.39181)        Denver   (39.762, -104.8758)
# 12603  (42.920673, -110.921776)         Ogden  (41.2279, -111.9682)
#
#       distance_to_maj_city_miles
# 0                     121.001418
# 1                     121.980045
# 2                      15.987941
# 3                      16.708137
# 4                      87.664428
# ...                          ...
# 12599                 132.340884
# 12600                 147.269952
# 12601                 241.450936
# 12602                 227.287741
# 12603                 128.625419
#
# [12604 rows x 27 columns]

# %% [markdown]
# ### Merge the crime datasets together

# %%
# if values in dataset 1 are in dataset 2 delete that value from dataset 1
crime_df_merged = pd.merge(crime_combined_df_revised, fbi_crime_df_revised, on = ['State', 'City'], how = 'outer', indicator = True)
crime_df_merged
# Out:
#      State                                  City  population_x  \
# 0       PA  Abington Township, Montgomery County       55731.0
# 1       OR                                Albany       51084.0
# 2       LA                            Alexandria       48449.0
# 3       CA                           Aliso Viejo       48999.0
# 4       FL                     Altamonte Springs       42296.0
# ...    ...                                   ...           ...
# 8165    WY                              Sheridan           NaN
# 8166    WY                           Thermopolis           NaN
# 8167    WY                            Torrington           NaN
# 8168    WY                             Wheatland           NaN
# 8169    WY                               Worland           NaN
#
#       violent_crime_x  prop_crime_x  larceny_x  vehicle_theft_x population_y  \
# 0            0.003542      0.035512   0.029621         0.000580        55476
# 1            0.001685      0.060545   0.048360         0.003602        54993
# 2            0.034721      0.154645   0.105313         0.007839        46630
# 3            0.001792      0.017286   0.012496         0.000541        52247
# 4            0.007937      0.072276   0.058247         0.003913        44582
# ...               ...           ...        ...              ...          ...
# 8165              NaN           NaN        NaN              NaN        17895
# 8166              NaN           NaN        NaN              NaN         2830
# 8167              NaN           NaN        NaN              NaN         6709
# 8168              NaN           NaN        NaN              NaN         3544
# 8169              NaN           NaN        NaN              NaN         5026
#
#      violent_crime_y prop_crime_y larceny_y vehicle_theft_y      _merge
# 0           0.000955     0.016836  0.015917        0.000342        both
# 1           0.001273     0.026676  0.022585        0.001764        both
# 2           0.015698     0.089642  0.065537        0.004975        both
# 3           0.000517     0.008288  0.006718        0.000478        both
# 4             0.0024     0.031582  0.027186        0.001907        both
# ...              ...          ...       ...             ...         ...
# 8165        0.000503      0.02062  0.015535        0.000894  right_only
# 8166        0.004594     0.012014  0.007774        0.001767  right_only
# 8167        0.001938     0.007155  0.005962             0.0  right_only
# 8168        0.001975     0.020316  0.012698        0.000847  right_only
# 8169        0.001592     0.007163  0.005969             0.0  right_only
#
# [8170 rows x 13 columns]

# %%
crime_merged_left = crime_df_merged[crime_df_merged['_merge'] == 'left_only'][['State', 'City', 'population_x', 'violent_crime_x', 'prop_crime_x', 'larceny_x', 'vehicle_theft_x']]
crime_merged_left.rename(columns = {'population_x': 'population', 'violent_crime_x': 'violent_crime', 'prop_crime_x': 'prop_crime', 'larceny_x': 'larceny', 'vehicle_theft_x': 'vehicle_theft'}, inplace=True)
crime_merged_left
# Out:
#     State          City  population  violent_crime  prop_crime   larceny  \
# 8      IA        Ankeny     46482.0       0.001573    0.029807  0.022355
# 13     AL        Auburn     54785.0       0.004397    0.063937  0.048311
# 31     OH      Boardman     40608.0       0.002608    0.102970  0.083141
# 60     MO  Chesterfield     47560.0       0.001018    0.033379  0.029487
# 73     TX        Conroe     59856.0       0.006168    0.057526  0.041896
# ..    ...           ...         ...            ...         ...       ...
# 922    NV     Las Vegas    627244.0       0.000987    0.004693  0.002607
# 925    NM   Albuquerque    561375.0       0.002439    0.013121  0.008463
# 934    PA  Philadelphia   1603797.0       0.000591    0.001910  0.001432
# 935    PA    Pittsburgh    305932.0       0.002145    0.010180  0.007733
# 937    TN     Nashville    674942.0       0.001686    0.005657  0.004158
#
#      vehicle_theft
# 8         0.000880
# 13        0.001699
# 31        0.003275
# 60        0.000885
# 73        0.003154
# ..             ...
# 922       0.000802
# 925       0.002438
# 934       0.000217
# 935       0.000727
# 937       0.000563
#
# [87 rows x 7 columns]

# %%
crime_merged_right = crime_df_merged[crime_df_merged['_merge'] == 'right_only'][['State', 'City', 'population_y', 'violent_crime_y', 'prop_crime_y', 'larceny_y', 'vehicle_theft_y']]
crime_merged_right.rename(columns = {'population_y': 'population', 'violent_crime_y': 'violent_crime', 'prop_crime_y': 'prop_crime', 'larceny_y': 'larceny', 'vehicle_theft_y': 'vehicle_theft'}, inplace=True)
crime_merged_right
# Out:
#      State                 City population violent_crime prop_crime   larceny  \
# 950     AK               Bethel       6544      0.019866   0.020171  0.012836
# 951     AK  Bristol Bay Borough        852      0.002347   0.023474   0.00939
# 952     AK              Cordova       2150           0.0   0.003256  0.002791
# 953     AK                Craig       1313      0.005331   0.015232  0.009139
# 954     AK           Dillingham       2405      0.020374   0.024116  0.015385
# ...    ...                  ...        ...           ...        ...       ...
# 8165    WY             Sheridan      17895      0.000503    0.02062  0.015535
# 8166    WY          Thermopolis       2830      0.004594   0.012014  0.007774
# 8167    WY           Torrington       6709      0.001938   0.007155  0.005962
# 8168    WY            Wheatland       3544      0.001975   0.020316  0.012698
# 8169    WY              Worland       5026      0.001592   0.007163  0.005969
#
#      vehicle_theft
# 950       0.004279
# 951       0.008216
# 952            0.0
# 953       0.002285
# 954       0.004158
# ...            ...
# 8165      0.000894
# 8166      0.001767
# 8167           0.0
# 8168      0.000847
# 8169           0.0
#
# [7220 rows x 7 columns]

# %%
crime_merged_both = crime_df_merged[crime_df_merged['_merge'] == 'both'][['State', 'City', 'population_y', 'violent_crime_y', 'prop_crime_y', 'larceny_y', 'vehicle_theft_y']]
crime_merged_both.rename(columns = {'population_y': 'population', 'violent_crime_y': 'violent_crime', 'prop_crime_y': 'prop_crime', 'larceny_y': 'larceny', 'vehicle_theft_y': 'vehicle_theft'}, inplace=True)
crime_merged_both
# Out:
#     State                                  City population violent_crime  \
# 0      PA  Abington Township, Montgomery County      55476      0.000955
# 1      OR                                Albany      54993      0.001273
# 2      LA                            Alexandria      46630      0.015698
# 3      CA                           Aliso Viejo      52247      0.000517
# 4      FL                     Altamonte Springs      44582        0.0024
# ..    ...                                   ...        ...           ...
# 945    TX                                 Plano     291611      0.001478
# 946    TX                           San Antonio    1559166      0.007085
# 947    VA                        Virginia Beach     449038      0.001294
# 948    WA                               Seattle     763706      0.005854
# 949    WI                             Milwaukee     590923      0.013325
#
#     prop_crime   larceny vehicle_theft
# 0     0.016836  0.015917      0.000342
# 1     0.026676  0.022585      0.001764
# 2     0.089642  0.065537      0.004975
# 3     0.008288  0.006718      0.000478
# 4     0.031582  0.027186      0.001907
# ..         ...       ...           ...
# 945   0.016831  0.013137      0.001533
# 946   0.043242  0.033011       0.00499
# 947   0.017607  0.015137      0.001289
# 948   0.044956  0.030742      0.004773
# 949   0.025548  0.013628      0.005838
#
# [863 rows x 7 columns]

# %%
crime_df_merged = pd.concat([crime_merged_left, crime_merged_right, crime_merged_both], ignore_index = True)
crime_df_merged
# Out:
#      State            City population violent_crime prop_crime   larceny  \
# 0       IA          Ankeny    46482.0      0.001573   0.029807  0.022355
# 1       AL          Auburn    54785.0      0.004397   0.063937  0.048311
# 2       OH        Boardman    40608.0      0.002608    0.10297  0.083141
# 3       MO    Chesterfield    47560.0      0.001018   0.033379  0.029487
# 4       TX          Conroe    59856.0      0.006168   0.057526  0.041896
# ...    ...             ...        ...           ...        ...       ...
# 8165    TX           Plano     291611      0.001478   0.016831  0.013137
# 8166    TX     San Antonio    1559166      0.007085   0.043242  0.033011
# 8167    VA  Virginia Beach     449038      0.001294   0.017607  0.015137
# 8168    WA         Seattle     763706      0.005854   0.044956  0.030742
# 8169    WI       Milwaukee     590923      0.013325   0.025548  0.013628
#
#      vehicle_theft
# 0          0.00088
# 1         0.001699
# 2         0.003275
# 3         0.000885
# 4         0.003154
# ...            ...
# 8165      0.001533
# 8166       0.00499
# 8167      0.001289
# 8168      0.004773
# 8169      0.005838
#
# [8170 rows x 7 columns]

# %% [markdown]
# ### Merge housing and crime datasets together

# %%
housing_crime_df = cleaned_housing_data.merge(crime_df_merged, on = ['City', 'State'])
housing_crime_df = housing_crime_df.drop(columns = ['population_x'])
housing_crime_df
# Out:
#      State         City                 Street  Zipcode  Bedroom  Bathroom  \
# 0       AL   Montgomery            Brampton Ln  36117.0      3.0       2.0
# 1       AL   Montgomery          Crestview Ave  36109.0      3.0       2.0
# 2       AL   Montgomery         Narrow Lane Rd  36116.0      3.0       3.0
# 3       AL   Montgomery           E Delano Ave  36105.0      3.0       2.0
# 4       AL   Montgomery  George B Edmondson Dr  36110.0      3.0       1.0
# ...    ...          ...                    ...      ...      ...       ...
# 9631    WY  Green River            Colorado Dr  82935.0      5.0       3.0
# 9632    WY   Evansville         Henrie Roadway  82636.0      2.0       2.0
# 9633    WY   Evansville                 6th St  82636.0      4.0       2.0
# 9634    WY   Evansville                 6th St  82636.0      3.0       3.0
# 9635    WY        Mills              N 4th Ave  82604.0      4.0       2.0
#
#         Area        PPSq  LotArea  MarketEstimate  ...          id  \
# 0     1564.0   96.547315   0.2000        150500.0  ...  1840008353
# 1     2196.0   76.958106   0.6100        124700.0  ...  1840008353
# 2     3693.0   54.156512   6.9000        188300.0  ...  1840008353
# 3     1428.0   90.966387   0.2600        127500.0  ...  1840008353
# 4     1050.0   65.714286   0.1600         66500.0  ...  1840008353
# ...      ...         ...      ...             ...  ...         ...
# 9631  3068.0  128.748370   0.2200        381000.0  ...  1840020100
# 9632  2008.0  343.625498   4.6000        689900.0  ...  1840021290
# 9633  2022.0  157.270030   0.1828        311100.0  ...  1840021290
# 9634  2300.0  143.434783   0.1739        329500.0  ...  1840021290
# 9635  2120.0   90.094340   0.3100        184600.0  ...  1840022359
#
#             house_coordinates  closest_city      city_coordinates  \
# 0     (32.372746, -86.165115)    Birmingham   (33.5279, -86.7971)
# 1      (32.39595, -86.269714)    Birmingham   (33.5279, -86.7971)
# 2      (32.273514, -86.25934)    Birmingham   (33.5279, -86.7971)
# 3         (32.337, -86.29974)    Birmingham   (33.5279, -86.7971)
# 4       (32.40325, -86.28537)    Birmingham   (33.5279, -86.7971)
# ...                       ...           ...                   ...
# 9631  (41.494328, -109.45258)         Provo  (40.2457, -111.6457)
# 9632   (42.86057, -106.10931)        Denver   (39.762, -104.8758)
# 9633   (42.86506, -106.27643)        Denver   (39.762, -104.8758)
# 9634   (42.86544, -106.27745)        Denver   (39.762, -104.8758)
# 9635  (42.851006, -106.39181)        Denver   (39.762, -104.8758)
#
#       distance_to_maj_city_miles population_y  violent_crime  prop_crime  \
# 0                      87.664428     209018.0       0.001893      0.0276
# 1                      83.806091     209018.0       0.001893      0.0276
# 2                      91.920847     209018.0       0.001893      0.0276
# 3                      87.007986     209018.0       0.001893      0.0276
# 4                      83.007626     209018.0       0.001893      0.0276
# ...                          ...          ...            ...         ...
# 9631                  143.591563        11927       0.001845    0.008133
# 9632                  223.247715         2977       0.002351    0.024521
# 9633                  226.191583         2977       0.002351    0.024521
# 9634                  226.233434         2977       0.002351    0.024521
# 9635                  227.287741         3975       0.000755    0.017862
#
#        larceny  vehicle_theft
# 0     0.017277        0.00252
# 1     0.017277        0.00252
# 2     0.017277        0.00252
# 3     0.017277        0.00252
# 4     0.017277        0.00252
# ...        ...            ...
# 9631  0.007043       0.000168
# 9632  0.017467       0.002687
# 9633  0.017467       0.002687
# 9634  0.017467       0.002687
# 9635  0.009811       0.002516
#
# [9636 rows x 31 columns]

# %%
housing_crime_df.to_csv('clean_housing_data_with_crime_rates.csv', index = False)

# %%
housing_crime_df.columns
# Out:
# Index(['State', 'City', 'Street', 'Zipcode', 'Bedroom', 'Bathroom', 'Area',
#        'PPSq', 'LotArea', 'MarketEstimate', 'RentEstimate', 'Latitude',
#        'Longitude', 'ListedPrice', 'density', 'source', 'military',
#        'incorporated', 'timezone', 'ranking', 'zips', 'id',
#        'house_coordinates', 'closest_city', 'city_coordinates',
#        'distance_to_maj_city_miles', 'population_y', 'violent_crime',
#        'prop_crime', 'larceny', 'vehicle_theft'],
#       dtype='object')
